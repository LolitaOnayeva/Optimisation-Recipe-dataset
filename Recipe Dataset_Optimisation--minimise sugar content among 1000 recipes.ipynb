# %%
import pandas as pd
import numpy as np
import csv
from pathlib import Path 
import re
import string

# %%
df= pd.read_csv(r'/Users/lolitalolita/Downloads/recipes.csv')

# %%
df
# Out:
#        RecipeId                                        Name  RecipeCategory  \
# 0         46085                 Crock Pot Baked Potato Soup   One Dish Meal
# 1         93832  Frittata Di Spaghetti (spaghetti Frittata)       Breakfast
# 2         36034                  Berries With Italian Cream         Dessert
# 3        329988  Pork Tenderloin Medallions With Fresh Figs       < 15 Mins
# 4         59886   Kaseropita (Tiropita Using Kaseri Cheese)     Savory Pies
# ...         ...                                         ...             ...
# 43087     22945                              Yummy Meatloaf            Meat
# 43088    110033                          Slow Cooker Shanks      Lamb/Sheep
# 43089    240945                    Sin-Free Chocolate Chews    Drop Cookies
# 43090    164157                      Montreal Salsa Chicken  Chicken Breast
# 43091    226759                  Skinny Green Chili Chicken  Chicken Breast
#
#        Calories  CholesterolContent  CarbohydrateContent  SugarContent  \
# 0         699.8               137.3                 46.1           1.4
# 1         297.1               191.8                 11.7           0.7
# 2         131.9                23.3                 10.3           4.4
# 3         203.0                74.8                  1.5           0.6
# 4         261.6               103.6                 20.9           0.2
# ...         ...                 ...                  ...           ...
# 43087     281.5               111.3                 13.2          11.1
# 43088     697.2               242.1                  3.8           1.9
# 43089      94.5                 0.0                 22.7          19.1
# 43090     207.1                72.6                 20.1          12.7
# 43091     296.4                47.4                 24.4           3.9
#
#        ProteinContent  RecipeServings  HighScore
# 0                20.9               6          1
# 1                12.2               8          1
# 2                 9.1               6          0
# 3                23.3               4          1
# 4                 6.7              15          1
# ...               ...             ...        ...
# 43087            25.3               6          1
# 43088            72.9               4          0
# 43089             2.0              14          1
# 43090            24.9               4          1
# 43091            15.2               3          1
#
# [43092 rows x 10 columns]

# %%
# Get first 1000 recipes 
df=df[:1000]

# %%
# Get calories and content per one serving
df_per_serving=df[['Calories','CholesterolContent','CarbohydrateContent','SugarContent','ProteinContent']].div(df.RecipeServings, axis=0)

# %%
df_per_serving
# Out:
#        Calories  CholesterolContent  CarbohydrateContent  SugarContent  \
# 0    116.633333           22.883333             7.683333      0.233333
# 1     37.137500           23.975000             1.462500      0.087500
# 2     21.983333            3.883333             1.716667      0.733333
# 3     50.750000           18.700000             0.375000      0.150000
# 4     17.440000            6.906667             1.393333      0.013333
# ..          ...                 ...                  ...           ...
# 995  371.700000          393.200000            27.800000      2.500000
# 996   46.366667            0.000000             7.066667      5.925000
# 997   21.366667            5.125000             2.508333      1.566667
# 998  119.000000            0.000000             3.200000      2.400000
# 999   12.100000            0.000000             3.125000      3.125000
#
#      ProteinContent
# 0          3.483333
# 1          1.525000
# 2          1.516667
# 3          5.825000
# 4          0.446667
# ..              ...
# 995       20.600000
# 996        0.233333
# 997        0.266667
# 998        0.100000
# 999        0.000000
#
# [1000 rows x 5 columns]

# %%
# Import PuLP modeler functions
from pulp import *

# %%
# Create the 'prob' variable to contain the problem data
prob = LpProblem("Minimal_sugar_intake", LpMinimize)
# Out:
# /Users/lolitalolita/opt/anaconda3/lib/python3.9/site-packages/pulp/pulp.py:1352: UserWarning: Spaces are not permitted in the name. Converted to '_'
#   warnings.warn("Spaces are not permitted in the name. Converted to '_'")

# %%
Name_dict = list(df['Name'])

Calories_dict = dict(zip(Name_dict, df_per_serving['Calories']))
CholesterolContent_dict = dict(zip(Name_dict , df_per_serving['CholesterolContent']))
CarbohydrateContent_dict = dict(zip(Name_dict , df_per_serving['CarbohydrateContent']))
SugarContent_dict = dict(zip(Name_dict, df_per_serving['SugarContent']))
ProteinContent_dict = dict(zip(Name_dict, df_per_serving['ProteinContent']))

# %%
# A dictionary called 'ingredient_vars' is created to contain the referenced Variables
recipe_name_vars = LpVariable.dicts("R", Name_dict, 0)

# %%
# The objective function is added to 'prob' first
prob += (
    lpSum([SugarContent_dict[i] * recipe_name_vars[i] for i in Name_dict]),
    "Total sugar content per dish",)

# %%
# The constraints are added to 'prob'

prob += (
    lpSum([Calories_dict[i] * recipe_name_vars[i] for i in Name_dict]) <= 2000.0,
    "Calories_dict_Requirement_max",
)
prob += (
    lpSum([Calories_dict[i] * recipe_name_vars[i] for i in Name_dict]) >= 1500.0,
    "Calories_dict_Requirement_min",
)


prob += (
    lpSum([CholesterolContent_dict[i] * recipe_name_vars[i] for i in Name_dict]) <= 13.0,
    "CholesterolContent_Requirement_max",
)
prob += (
    lpSum([CholesterolContent_dict[i] * recipe_name_vars[i] for i in Name_dict]) >= 5.0,
    "CholesterolContent_Requirement_min",
)

prob += (
    lpSum([CarbohydrateContent_dict[i] * recipe_name_vars[i] for i in Name_dict]) <= 150.0,
    "CarbohydrateContent_Requirement_max",
)

prob += (
    lpSum([CarbohydrateContent_dict[i] * recipe_name_vars[i] for i in Name_dict]) >= 120.0,
    "CarbohydrateContent_Requirement_min",
)

prob += (
    lpSum([ProteinContent_dict[i] * recipe_name_vars[i] for i in Name_dict]) <= 112.0,
    "ProteinContent_Requirement_max",
)
prob += (
    lpSum([ProteinContent_dict[i] * recipe_name_vars[i] for i in Name_dict]) >= 70.0,
    "ProteinContent_Requirement_min",
)

# %%
# The problem data is written to an .lp file
prob.writeLP("RecipeModel.lp")
# Out:
# [R_"All_in_the_Kitchen"_Chili,
#  R_(Fake)_Crab_Stroganoff,
#  R_*s.w.o.c.*_Pie_Cookies,
#  R_3_Dragon’s_Szechuan_Steak,
#  R_4_Bean_Relish,
#  R_5_Ingredient_Crescent_Roll_Breakfast_Bake,
#  R_5_Layer_Italian_Dip,
#  R_7_Minute_Rich_and_Creamy_Polenta,
#  R_99_Bananas_and_a_Coconut_Cocktail,
#  R_A_Leg_up_(Oven_Fried_Drumsticks),
#  R_Aam_Lhassi,
#  R_Aaron_Tippin's_Mexican_Casserole,
#  R_Acorn_Squash_Soup,
#  R_Addictive_Chocolate_Tapioca_Pudding,
#  R_All_American_Pancakes,
#  R_Almond_Crusted_Chicken_Breast,
#  R_Almond_Shortbreads,
#  R_Amazing_Apple_Pie,
#  R_Amazing_Baked_Lemon_Garlic_Chicken_Thighs_and_Potatoes,
#  R_American_Girl_Magazine's_Colorful_Cake,
#  R_An_Oatmeal_Poached_Egg,
#  R_Annabel's_Homemade_Granola,
#  R_Annie's_Turkey_Salad,
#  R_Antipasto_Squares,
#  R_Anytime_Pizza_Casserole,
#  R_Apple_Cinnamon_Oatmeal,
#  R_Apple_Oven_Pancake,
#  R_Apple_Romaine_Salad,
#  R_Apple_Strawberry_Rhubarb_Crisp,
#  R_Apple_Stuffed_Tenderloin_With_Cinnamon_Raisin_Sauce,
#  R_Apple_Upside_Down_Cake,
#  R_Apple_Wrap_Sandwich,
#  R_Apples_and_Ground_Beef_Pasta,
#  R_Apricot_Bars,
#  R_Apricot_Nut_Bread,
#  R_Arabic_Almond_Milk,
#  R_Arabic_Cardamom_Shortbread_(Gorayba),
#  R_Arroz_Con_Gandules,
#  R_Arroz_Con_Gandules_(Rice_and_Pigeon_Peas)_A_Puerto_Rican_Fav,
#  R_Artichoke_Cheese_Balls,
#  R_Asian_Sugar_Snap_Peas,
#  R_Asian_Turkey_or_Chicken_Salad_With_Mandarin_Balsamic_Vinaigrette,
#  R_Asian_Vegetable_Soup,
#  R_Asparagus_Lasagna,
#  R_Asparagus_Tarts,
#  R_Aunt_Jemima_Cornbread,
#  R_Authentic_Mexican_Tomato_Rice,
#  R_Avocado,_Sun_Dried_Tomato_and_Mozzarella_Stuffed_Chicken_Breast,
#  R_Avocado_Crabmeat_Sandwiches,
#  R_Bacon_Wrapped,_Cream_Cheese_Stuffed_Chicken_Breasts,
#  R_Baked_Acorn_Squash_&amp;_Brown_Sugar,
#  R_Baked_Beans_1998,
#  R_Baked_Cheese_Crepes___Giada_De_Laurentiis,
#  R_Baked_Cheese_Grits_Casserole,
#  R_Baked_Chicken_Tagliatelle_With_Mushrooms_and_Peppers,
#  R_Baked_Chicken_w__light_sauce,
#  R_Baked_Chickpea_Falafel,
#  R_Baked_Corn_on_the_Cob,
#  R_Baked_Fish_Fillets,
#  R_Baked_Flounder_With_Lemon,_Parsley_and_Bread_Crumbs,
#  R_Baked_Garlic_Chicken,
#  R_Baked_Graham_Cracker_French_Toast,
#  R_Baked_Parmesan_Breaded_Fish,
#  R_Baked_Stuffed_Polenta_(Polenta_Al_Forno),
#  R_Baked__Fish__Almondine,
#  R_Balsamic_Fried_Eggs_With_Wilted_Greens_(In_Under_10_Minutes),
#  R_Banana_Nut_Muffins_(Sbd_Phase1),
#  R_Bars_of_Iron,
#  R_Batter_Fried_Fresh_Tomatoes,
#  R_Bayou__Salad,
#  R_Beef_Teriyaki,
#  R_Beef_and_Mushroom_topped_Potato_Wedges,
#  R_Beer_Battered_Shrimp_With_Chipotle_Honey_Sauce,
#  R_Bek's_Grilled_Tuna_Steaks_Glazed_With_Ginger,_Lime,_and_Soy_OAMC,
#  R_Belgian_Fries_With_Andalouse_Sauce,
#  R_Berries_With_Italian_Cream,
#  R_Berry_Tossed_Salad,
#  R_Best_Ever_Fried_Rice,
#  R_Best_Ham_and_Split_Pea_Soup,
#  R_Big_Boy's_Tartar_Sauce_Clone___Copycat,
#  R_Big_Mac_Sauce_Low_Fat,
#  R_Bird_Nests,
#  R_Bisquick_Tuna_Pie,
#  R_Bistro_Steak_Sandwich_With_Seasoned_Potato_Chips,
#  R_Black_Bean_&amp;_Corn_Salad,
#  R_Black_Jack_Martini,
#  R_Black_Raspberry_Margarita,
#  R_Black_Russian,
#  R_Blazing,_I_Mean_Braising_Pork_and_Red_Lentils,
#  R_Bloody_Blast,
#  R_Blue_Cheese_Spread,
#  R_Blueberry_Banana_Snack_Cakes,
#  R_Bob_Evans_Style_Buttermilk_Biscuits,
#  R_Bok_Bok_Popovers,
#  R_Bourbon_Pecan_Pie,
#  R_Bourbon_Pecan_Pound_Cake,
#  R_Braised_Hoisin_Beer_Short_Ribs,
#  R_Breakfast_Casserole_from_Southern_Living,
#  R_Brenda's_Famous_Potato_Salad,
#  R_Brined_Pork_Chops,
#  R_Broccoli_&amp;_Onion_Casserole,
#  R_Broccoli_Casserole,
#  R_Broccoli_Cheese_Skillet_Potatoes,
#  R_Broccoli_Lovers_Casserole_II,
#  R_Broccoli_Rabe,_White_Bean,_and_Fontina_Pasta,
#  R_Broccoli_Salad,
#  R_Broiled_Salmon_With_Chili_Glaze,
#  R_Broiled_Turkey_over_Spinach,
#  R_Brown_Rice_Perfection,
#  R_Brown_Sugar_Oatmeal_Muffins,
#  R_Browned_Butter_and_Hazelnut_Mashed_Potatoes,
#  R_Brussels_Sprouts,
#  R_Brussels_and_Shrooms_Saute,
#  R_Buckwheat_and_Yam_Tortillas_With_Stir_Fry,
#  R_Buffalo_Chicken_Dip,
#  R_Buffalo_Chicken_Tenders_or_Fingers,
#  R_Bunya_Calda_(Or_Banya_Cauda),
#  R_Burnished_Bananas,
#  R_Buttermilk_Pudding_With_Fresh_Fruit,
#  R_Cabbage_Pie,
#  R_Caesar_Burgers,
#  R_Caesar_Salad,
#  R_Cajun_Chicken_Linguine,
#  R_Cajun_Chicken_and_Linguine,
#  R_Cajun_Meat_Loaf_With__a_Cool_Tomato_Salsa,
#  R_Calamari_in_Creamy_Wine_Sauce,
#  R_Calci_Yum_Protein_Drink,
#  R_Calico_Peas,
#  R_Canadian_Bacon,_Apples_and_Potatoes,
#  R_Canadian_Oven_Roasted_Potatoes,
#  R_Caramel_Cheesecake_With_Hazelnut_Crust,
#  R_Caramel_Pecan_Cookies,
#  R_Caramel_Snack_Mix,
#  R_Caramelized_Banana_Buttermilk_Ice_Cream,
#  R_Caribbean_Sweet_Potato_Coconut_Soup,
#  R_Carol's_Muffalletto,
#  R_Carrot_Salad_With_Pineapple_(No_Mayo),
#  R_Cauliflower_With_Herbed_Crumb_Topping,
#  R_Cauliflower_and_Cheese_Pakora,
#  R_Cauliflower_and_Chicken_Casserole,
#  R_Champagne_Raspberry_Sauce,
#  R_Cheerios_Jumbo_Breakfast_Cookies,
#  R_Cheese_&amp;_Pesto_Bites,
#  R_Cheese_Enchiladas_With_Green_Sauce,
#  R_Cheese_Frankfurters,
#  R_Cheese_Nip_Broccoli_Casserole,
#  R_Cheese_Rosti,
#  R_Cheese_and_Egg_Puffs,
#  R_Cheese_and_Jalapeno_Grits_Casserole,
#  R_Cheesy_Cheez_It_Mac_&amp;_Cheese,
#  R_Cheesy_Crust_Roasted_Haddock,
#  R_Cheesy_Italian_Wedding_Soup,
#  R_Cheesy_Sausage_Penne,
#  R_Cheesy_Vegetable_Pasta,
#  R_Chicken,_Grape_and_Curry_Salad,
#  R_Chicken,_Pasta,_and_Chickpea_Stew,
#  R_Chicken,_Tomato,_Zucchini,_and_Orzo_Stew,
#  R_Chicken_&amp;_Artichoke_Lasagne,
#  R_Chicken_Amandine,
#  R_Chicken_Breast_With_Red_Pepper_Cream_Sauce,
#  R_Chicken_Breasts_With_Mushrooms,
#  R_Chicken_Burgurs,
#  R_Chicken_Cacciatore,
#  R_Chicken_Cobbler_Casserole,
#  R_Chicken_Kiev,_a_Yummy_&amp;_Healthy_Version,
#  R_Chicken_Liver_Pate:_Terrine_De_Foies_De_Volaille,
#  R_Chicken_Noodle_Soup_(Ina_Garten's_Recipe),
#  R_Chicken_Parmesan_With_Fresh_Mozzarella_and_Fresh_Basil,
#  R_Chicken_Pot_Pie_With_Biscuit_Topping,
#  R_Chicken_Salad,
#  R_Chicken_Scampi,
#  R_Chicken_Soup_for_Dummies,
#  R_Chicken_Spinach_Salad_With_Raspberries,
#  R_Chicken_Stuffed_&quot;_Chili&quot;_Bell_Peppers,
#  R_Chicken_With_Fresh_Tomato_Cilantro_Cream_Sauce,
#  R_Chicken_With_Noodles_and_Vegetables_(Ww),
#  R_Chicken_With_Rice_and_Fruit_Salad,
#  R_Chicken_a_La_Queen_;),
#  R_Chicken_and_Black_Bean_Chili__Crock_Pot,
#  R_Chicken_and_Green_Chili_Enchiladas,
#  R_Chicken_and_Roasted_Pepper_Panini,
#  R_Chicken_and_Salad_Pizza(Flat_Belly_Diet_Recipe),
#  R_Chicken_and_Ziti_With_Asparagus_in_a_Creamy_Sauce,
#  R_Chicken_in_Tarragon_and_Wine_Sauce_Vol_Au_Vents,
#  R_Chicken_or_Pork_Stuffed_Capsicums_Bell_Peppers,
#  R_Chickpea_Sandwich_Filling,
#  R_Chili_Sausage_Supper,
#  R_Chilli_Crab_Linguine_With_Vodka,
#  R_Chinese_Chicken_Noodle_Soup,
#  R_Chinese_Mustard_Vinaigrette,
#  R_Chinese_Sweet_Almond_Cookies,
#  R_Chipits_Tiger_Bars,
#  R_Chipped_Beef_Chip_Dip,
#  R_Choco_Chip_Cookies,
#  R_Choco_Hoto_Pots___Nigella_Lawson,
#  R_Chocolate_Chip_Bread_Pudding,
#  R_Chocolate_Chip_Cream_Cheese_Pound_Cake,
#  R_Chocolate_Dipped_Ginger,
#  R_Chocolate_Dipped_Spritz_Cookies,
#  R_Chocolate_Eclair_Cake,
#  R_Chocolate_Milkshake,
#  R_Chocolate_Mousse_(foolproof_version!),
#  R_Chocolate_Mousse_Cake,
#  R_Chocolate_Strawberry_Pie,
#  R_Chocolate_and_Coconut_Pie,
#  R_Chopped_Bug_&amp;_Beetle_Juice_(After_School_Drink),
#  R_Chris's_Tater_Tot_Casserole,
#  R_Chrissy's_Chicken_Thighs,
#  R_Christmas_Minties,
#  R_Chunky_Caesar_Salad,
#  R_Chutney_Rum_Chicken,
#  R_Cinnamon,_Pumpkin_and_Blueberry_Oatmeal,
#  R_Cinnamon_Apple_Crumble,
#  R_Cinnamon_Apple_Muffins,
#  R_Cinnamon_Coffee_Cake_Muffins,
#  R_Cinnamon_Raisin_Bread_Pudding,
#  R_Cinnamon_Rice_Pudding_Mix,
#  R_Cinnamon_Syrup,
#  R_Classic_Fish_and_Chips,
#  R_Classic_Macaroni_Salad,
#  R_Classic_White_Bread_for_the_Bread_Machine,
#  R_Clove_Spiced_Apples,
#  R_Club_Sandwiches,
#  R_Cochinita_Pibil,
#  R_Coconut_Chicken_Salad,
#  R_Cod_Curry,
#  R_Coffee_Angel_Food_Cake,
#  R_Coffee_for_the_Damned,
#  R_Cold_Calanda_Peach_Soup___Sopa_Fria_De_Melocot&oacute;n_De_Calan,
#  R_Cold_Poached_Trout,
#  R_Cold_Salmon_With_Mustard_Sauce_Recipe,
#  R_Colorful_Pea_Salad,
#  R_Comforting_Butternut_Squash_Soup_Recipe,
#  R_Cookie_Crusted_Rhubarb_Bars,
#  R_Copycat_Chevys_Ultimate_Orange_Margarita,
#  R_Coriander_Crusted_Tuna_With_Black_Bean_Salsa,
#  R_Corn_Uttapam,
#  R_Corn_and_Black_Eyed_Pea_Salad,
#  R_Cornmeal_and_Cumin_Pork_Loin,
#  R_Country_Bread,
#  R_Country_Ribs_City_Chicken,
#  R_Crab_Imperial_(Baltimore_Style),
#  R_Crab_Meat_or_Shrimp_Omelette,
#  R_Crabmeat_or_Salmon_Patties,
#  R_Cranberry,_Orange_Cream_Cheese_Smoothie!,
#  R_Cranberry_Orange_Buttermilk_Muffins,
#  R_Crazy_Good_Cowboy_Coffee_Cake,
#  R_Cream_Cheese_Cucumber_Bites_(Kids_Sailboats),
#  R_Creamed_Corn_With_Bacon,
#  R_Creamed_Finnan_Haddie_(Smoked_Haddock),
#  R_Creamed_Mashed_Potatoes_(From_Instant),
#  R_Creamed_Red_Potatoes_And_Green_Beans,
#  R_Creamy_Basil_and_Sun_Dried_Tomato_Vegan_Pasta,
#  R_Creamy_Chicken_or_Pork_Cacciatore_in_Crock_Pot,
#  R_Creamy_Delite,
#  R_Creamy_Dreamy_Potatoes,
#  R_Creamy_Macaroni_and_Cheese,
#  R_Creamy_Sweet_Potato_Soup,
#  R_Creamy_Tomato_Soup,
#  R_Creamy_Vanilla_Pudding,
#  R_Creole_Black_Eyed_Peas,
#  R_Creole_Seasoning,
#  R_Crisp_Goat_Cheese_Salad,
#  R_Crispy_Baked_Chicken_Breasts,
#  R_Crispy_Gruyere_Potato_Wedges,
#  R_Crispy_Parm__Crusted_Filet_of_Fish,
#  R_Croatian_Chicken_“paprikas”,
#  R_Croatian_Slavonian_Fish_Stew_(ï¿½fiï¿½ï¿½),
#  R_Crock_Pot_Baked_Potato_Soup,
#  R_Crock_Pot_Balsamic_Chicken,
#  R_Crock_Pot_Barley_Casserole,
#  R_Crock_Pot_Beef_and_Noodles,
#  R_Crock_Pot_Ham_and_Beans,
#  R_Crock_Pot_Lil_Smokies,
#  R_Crock_Pot_Sausage_and_Potatoes,
#  R_Crunchy_Apple_Beef,
#  R_Cuban_Pork_Stew,
#  R_Cucumber_Salad_With_Rice_Vinegar_Dressing,
#  R_Cucumbers_and_Mint_Salad,
#  R_Curried_Carrot_and_Coriander_Soup,
#  R_Curried_Cauliflower,
#  R_Curried_Cheese_Pate,
#  R_Curried_Corn_Salad,
#  R_Curried_Couscous_Salad_With_Dried_Cranberries,
#  R_Curried_Pickled_Fish,_Old_Traditional_South_African_Recipe,
#  R_Curried_Zucchini_Soup,
#  R_Daddy's_Chicken_and_Dumplings,
#  R_Danish_Coffee,
#  R_Danish_Roast_Goose_with_Prunes_&_Apples,
#  R_Darcie's_Green_Pepper_Sandwiches,
#  R_Dark_Chocolate_Bark,
#  R_Dead_Green_Frog,
#  R_Deep_Vegan_Cake_(Chocolate_Cake)_Made_Lighter,
#  R_Delhi_Style_Egg_Curry,
#  R_Delicious_Lemon__Cake,
#  R_Delicious_Low_Fat_One_Dish_Pasta_Dinner,
#  R_Delish_Grilled_Pineapple_from_Alton_Brown,
#  R_Deluxe_Sourdough_Bread,
#  R_Denver_Style_Frittata,
#  R_Depression_Era_Apple_Candy_Pie,
#  R_Desert_Island_Green_Salad,
#  R_Devastatingly_Delicious_Meatloaf___the_Best_You_Ever_Had!!!!!!!!,
#  R_Diabetic_Blueberry_Scones,
#  R_Digby_Scallops_and_Clams_Sauteed_in_Canadian_Whiskey,
#  R_Dilled_Spring_Potato_Salad,
#  R_Donna's_Easy_Beef_Stroganoff,
#  R_Double_Dark_Chocolate_Walnut_Cookies,
#  R_Dr._Weil's_Barley_and_Vegetable_Soup,
#  R_Dragon_Fly,
#  R_Dry_Onion_Soup_Mix_(Replacer),
#  R_Dutch_Beets,
#  R_East_West_Barbecued_Chicken_(Crock_Pot),
#  R_Easter_Peanut_Butter_Bunny_Crisp_Cake,
#  R_Easy_&amp;_Tasty_Chicken_Tortilla_Soup,
#  R_Easy_(Mostly_Traditional)_Caesar_Salad,
#  R_Easy_Banana_Nut_Bread,
#  R_Easy_Beef_Roll_Ups,
#  R_Easy_Breakfast,
#  R_Easy_Cherry_Cheesecake,
#  R_Easy_Chicken_Schnitzel,
#  R_Easy_Crispy_Dijon_Chicken,
#  R_Easy_Fixin’_Arr&oacute;z_Con_Pollo_(Rice_With_Chicken),
#  R_Easy_Ham_and_Bean_Soup,
#  R_Easy_Lemon_Mousse,
#  R_Easy_Lime_Cream_Pie,
#  R_Easy_Mexican_Calzones,
#  R_Easy_Oatmeal_Raisin_Cookies,
#  R_Easy_Praline_Pumpkin_Pie,
#  R_Eggnog_French_Toast,
#  R_Eggplant_(Aubergine)_and_Tomato_Crisp,
#  R_Eggplant_Mozzarella_Tower,
#  R_Egyptian_Sahlab_or_Sahlep,
#  R_El_Torito's_Kahlua_Mousse,
#  R_Elegant__Garlic_Chicken_for_Two,
#  R_Emeril's_Chocolate_Malted_Shake,
#  R_English_Cottage_Pie,
#  R_Everyday_is_Thanksgiving_in_a_Loaf!,
#  R_Fabulous_French_Bread,
#  R_Fake_Mashed_Potatoes_Cauliflower,
#  R_Fakes_Salata_(Lentil_Salad),
#  R_Fantastic_Mushrooms_With_Garlic_Butter_and_Parmesan,
#  R_Fantastic__Chicken_Piccata,
#  R_Farm_Fresh_Omelet,
#  R_Fat_Free_Sugar_Free_Brownies,
#  R_Faux_Moussaka_With_Lentils,
#  R_Fennel_and_Apple_Salad,
#  R_Feta_&amp;_Red_Onions,
#  R_Feta_Stuffed_Turkey_Burgers,
#  R_Fettuccini_With_Chicken_Breasts,
#  R_Figs_With_Marsala_and_Orange,
#  R_Firecracker_Shortcake,
#  R_Fish_Fillets_in_Tomato_Cream,
#  R_Five_Cheese_Noodle_Casserole,
#  R_Five_Spice_Chicken_With_Noodles,
#  R_French_Breakfast_Muffins,
#  R_French_Oven_Stew,
#  R_French_Toast_With_Brown_Sugar,
#  R_Fresh_Herb_Rubbed_Salmon_Fillets,
#  R_Fresh_Plum_Flan,
#  R_Fresh_Tomato,_Basil,_and_Cheese_Pizza,
#  R_Fresh_Tomato_Soup_With_Rice,
#  R_Frexca,
#  R_Frittata_Di_Spaghetti_(spaghetti_Frittata),
#  R_From_Scratch_Tuna_Noodle_Casserole,
#  R_Frozen_Peanut_Butter_Banana_Pops,
#  R_Fruit_Crunch_Sundae,
#  R_Fruit_Salad_Pudding,
#  R_Fruit_Smoothie,
#  R_Fudgy_Cherry_Cheesecake_Brownie_Bars,
#  R_Garlic_&_Red_Wine_Vinegar_Salad_Dressing,
#  R_Garlic_Mushroom_Risotto,
#  R_Garlic_Mustard_Steak_Salad,
#  R_Garlic_Roasted_Chicken_With_Maple_Glaze,
#  R_Garlic_Scallops_With_Angel_Hair_Pasta,
#  R_Garlic_Soup_That_Cures_What_Ails_You_(Aka_Hangover_Soup),
#  R_Giada_De_Laurentiis's_Penne_With_Spinach_Sauce,
#  R_Ginger_Curry_Pork_and_Rice,
#  R_Ginger_Garlic_Bread,
#  R_Ginger_Lime_Fish_Parcels,
#  R_Gingerbread_Boxes,
#  R_Gingered_Tuna_Salad,
#  R_Glazed_Bacon,
#  R_Glazed_Pound_Cake___Gluten_Free,
#  R_Glen's_Spanish__Chicken_and_Rice,
#  R_Gluten_Free_Lemon_Bars,
#  R_Gluten_Free_Tropical_Rice,
#  R_Gluten_Free_Vegan_Zucchini_Eggplant_Lasagna,
#  R_Goat_Cheese,_Arugula_and_Strawberry_Salad,
#  R_Golabki___Polish_Stuffed_Cabbage,
#  R_Golden_Diced_Potatoes_II,
#  R_Golden_Northern_Cornbread__With_Bacon,
#  R_Golden_Pumpkin_Cake_with_Cinnamon_Frosting,
#  R_Golden_Raisin_Bars.,
#  R_Goldman's_Coffee_Cake,
#  R_Grace's_Potato_Casserole,
#  R_Grandma_Tuttle's_Beach_Rice,
#  R_Gravlax,
#  R_Greek_Feta_Dip,
#  R_Greek_Frittata_With_Spinach,_Oregano_and_Feta_Cheese,
#  R_Greek_Pasta_Salad,
#  R_Green_Beans_With_Bacon,
#  R_Green_Chili_Puff,
#  R_Grilled_Breakfast_Pizza,
#  R_Grilled_Cajun_Chicken,
#  R_Grilled_Chicken_Salad_With_Raspberry_Vinaigrette,
#  R_Grilled_Cream_Cheese_Sandwich,
#  R_Grilled_Cumin_Marinated_Swordfish,
#  R_Grilled_Pineapple_Salad,
#  R_Grilled_Savory_Brussels_Sprouts,
#  R_Ground_Beef_Casserole_With_Almonds,
#  R_Ground_Beef_Pizza,
#  R_Guyana_Pepper_Pot,
#  R_Ham_and_Cheese_Loaf,
#  R_Ham_and_Havarti_Crostini,
#  R_Ham_and_Zucchini_Risotto,
#  R_Hampshire_Fruit_Cobbler,
#  R_Hashed_Brussels_Sprouts_With_Fresh_Oregano,
#  R_Haupia_Cheesecake,
#  R_Hawaiian_Bread_for_Abm,
#  R_Hawaiian_Pineapple_Cobbler,
#  R_Hawaiian_Shrimp_Truck_Special_(Garlic_Lemon_Butter_Shrimp),
#  R_Hazie_Morning_Latte,
#  R_Healthy_Bran_Muffins,
#  R_Healthy_Creamy_Parmesan_Mashed_Potatoes,
#  R_Healthy_Fruit_Parfait,
#  R_Hearty_Garlic_Potato_Soup,
#  R_Herb_Cheese_Sauce_for_Fish,
#  R_Herbed_Mashed_Potatoes,
#  R_Hg_Pumpkin_Enchiladas,
#  R_Hodgepodge,
#  R_Holiday_Ring_Cake,
#  R_Homemade_Spaghetti_Pasta_Sauce,
#  R_Hominy_Sausage_Bake,
#  R_Honey_Almond_Dip_for_Strawberries,
#  R_Honey_Basil_Grilled_Chicken,
#  R_Honey_Chicken,_Panama,
#  R_Honey_Ginger_Glazed_Chicken,
#  R_Honey_Pecan_Chicken_Salad,
#  R_Honey_Raspberry_Iced_Tea,
#  R_Honey_and_Garlic_Dressing_2,
#  R_Hot_Caramel_Apple_Cider,
#  R_Hot_Fudge_&amp;_Caramel_Ice_Cream_Pie,
#  R_Hot_Mulled_Apple_Cider,
#  R_Hot_Skillet_Pizza,
#  R_Hot_Tiramisu_Drink,
#  R_Hulda's_Krumkake,
#  R_Hummus,
#  R_Hungarian_Poppy_Seed_Coffee_Cake,
#  R_Hungarian_Potato_and_Egg_Casserole,
#  R_Impressive_Lettuce_Salad,
#  R_Incredible_Melted_Ice_Cream_Cake_With_Chocolate_Marshmallow_Fros,
#  R_Indian_Grilled_Sour_Cream–marinated_Shrimp,
#  R_Indian__Tomato_Kachambur,
#  R_Individual_Cherry_Tiramisu_Dessert__Cups,
#  R_Individual_Vegetable_Lasagnas,
#  R_Indonesian_Curried_Vegetables,
#  R_Injected_Chocolate_Covered_Strawberries_With_Grand_Marnier,
#  R_Inside_Out_Chicken_Pot_Pie,
#  R_Irish_Coffee,
#  R_Irish_Vanilla_Coffee,
#  R_Italian_Cupboard_Soup,
#  R_Italian_Fish_Portions,
#  R_Italian_Green_Beans,
#  R_Italian_Herb_Salad_Dressing_Mix_Clone,
#  R_Italian_Potato_Salad,_Gorgonzola,_and_Orange_Balsamic_Dressing,
#  R_Italian_Sausage_&_Pasta,
#  R_Italian_Steak,
#  R_Italian_Turkey_Sausage,
#  R_Jack_Daniel's_Fudge,
#  R_Jackie's_Spin_Dip,
#  R_Jalapeno_Popper_Spread,
#  R_Jamaican_Rum_Cake,
#  R_Jamie_Oliver's_Easy_Quick_Spaghetti,
#  R_Julia_Child_Chopped_Brussels_Sprouts_in_Cream,
#  R_Kaddo_Bourani_(Afghani_Baked_Pumpkin_With_Yogurt_Sauce),
#  R_Kai_Si_Ming,
#  R_Kaseropita_(Tiropita_Using_Kaseri_Cheese),
#  R_Kelly's_Moo_Shu_Pork_(Or_Beef)_Pockets,
#  R_Kentucky_Kernel_Oven_Baked_Pork_Chops,
#  R_King_Ranch_Chicken,
#  R_Kittencal's_Baked_Potato_Salad_Casserole_(Or_Cold_Potato_Salad),
#  R_Kittencal's_Italian_Zucchini_Mozzarella_Patties,
#  R_Kona_K's_Beef_&amp;_Veggie_Dinner_for_Doggies,
#  R_Kuba_Cuba,
#  R_Kung_Pao_Chicken,
#  R_Lamb_in_Pureed_Spinach_(Saag_Gosht),
#  R_Layered_Banana_&amp;_Oat_Bars,
#  R_Layered_Fruit_Salad,
#  R_Lazy_New_England_Clam_Chowder,
#  R_Lazy_Peach_Pie,
#  R_Lea_and_Perrins_Lamb_Chops,
#  R_Leek_Frittata,
#  R_Leek_and_Caper_Salad,
#  R_Leftover_Pizza_Frittata_(Using_Leftover_Pizza!),
#  R_Leftover_Steak_and_Potato_Breakfast,
#  R_Lemon_Drop_Cookies,
#  R_Lemon_Kale,
#  R_Lemon_Soda,
#  R_Lemon_Verbena_Pound_Cake,
#  R_Lemonade_Pie,
#  R_Lemony_Lettuce_Nestled_Ranch_Pork_Sliders_#RSC,
#  R_Lentil_Soup,
#  R_Lentil_and_Golden_Squash_Pot_Pie,
#  R_Light_and_Yummie_Strawberry_Pie,
#  R_Lighter_Parmesan_Spinach_Stuffed_Potatoes_With_Vegan_Variation,
#  R_Lime_Cilantro_Butter_Shallot_Butter,
#  R_Linda's_King_of_the_Piggies,
#  R_Loobia_Polow,
#  R_Louisiana_Style_Crab_Nibblers,
#  R_Low_Cal_Mug_Cake,
#  R_Low_Calorie_Turkey_Casserole,
#  R_Low_Carb_Bacon_Wrapped_Chicken_Tenders,
#  R_Low_Carb_Low_Fat_Pumpkin_Muffins,
#  R_Low_Fat_Pumpkin_Soup_in_Microwave,
#  R_Low_Fat_Stuffed_Pasta_Shells,
#  R_Low_Salt_Savoury_Rice,
#  R_Low_Sodium_Tomato_Soup,
#  R_Lunch_Quiche,
#  R_Make_Ahead_Salad,
#  R_Makeover_Frozen_Mocha_Cheesecake_Loaf,
#  R_Malaysian_Portuguese_Eurasian_Yellow_Curry__Too_Easy,
#  R_Malaysian_Style_Oxtail_Soup,
#  R_Mamie_Eisenhower's_Favorite_Million_Dollar_Fudge,
#  R_Maple_Cream_Berries_&amp;_Walnut_Ice_Cream_Rachael_Ray,
#  R_Maple_Milk,
#  R_Maple_Mousse_Recipe,
#  R_Maple_Pumpkin_Saut&eacute;,
#  R_Maple_Roasted_Root_Vegetables,
#  R_Maple_Syrup_Dumplings,
#  R_Marinara_Sauce,
#  R_Mario_Batali's_Fettuccine_Bolognese,
#  R_Marshmallow_Brownies,
#  R_Marshmallow_Cinnamon_Rice_Krispies_Bars,
#  R_Marshmallow_Nachos,
#  R_Mashed_Potato_Skins,
#  R_Maui_Sipper,
#  R_Mean_Guy's_General_Tso's_Chicken,
#  R_Meatloaf_Muffin_Cakes,
#  R_Melissa's_Minute_Minestrone,
#  R_Meringue_Kisses,
#  R_Mesopotamian_Barley,_Lentil_and_Tahini_Soup_(Vegan),
#  R_Mexican_Chicken_Tortilla_Skillet,
#  R_Mick_Mcgurk's_Cheese_Biscuits_(Cookies),
#  R_Microwave_Pumpkin_Custard,
#  R_Middle_Eastern_Chicken_Burgers,
#  R_Migas_Lite_for_2,
#  R_Mini_Chip_Buttercream,
#  R_Mini_Jalapeno_Muffins,
#  R_Mint_Tea_Syrup,
#  R_Mixed_Berry_Sauce,
#  R_Mmmm_Fast_Hoisin_Pork_Stir_Fry,
#  R_Mocha_Bundt_Cake,
#  R_Molasses_Refrigerator_Muffins,
#  R_Mom's_Favorite_Fruitcake,
#  R_Mom's_Slaw,
#  R_Mom's_Zucchini,_Tomato_&amp;_Italian_Sausage_With_Mozzarella,
#  R_Momma_Dips_Creamed_Peas_With_Pearl_Onions,
#  R_Moravian_Christmas_Cookies,
#  R_Morning_Buns(Cook's_Country),
#  R_Moroccan_Citrus_Fruit_Salad,
#  R_Moroccan_Meatballs_in_Tomato_Sauce,
#  R_Moroccan_Spiced_Carrot_Soup,
#  R_Mulled_Holiday_Tea,
#  R_Mums_'scotch'_Pancakes,
#  R_Mushroom_Bisque,
#  R_Mushroom_Ravioli,
#  R_Mushroom_Sauced_Pot_Roast_for_the_Crock_Pot,
#  R_Mushroom_and_Onion_Smothered_Swiss_Steak,
#  R_Mushrooms_la_Grecque,
#  R_Mussels_Luxembourg_Style,
#  R_Mustard_Mousse,
#  R_My_Famous_Chili_Con_Carne,
#  R_My_Kids_Breakfast_Smoothie,
#  R_My_Perfect_Oatmeal,
#  R_My_Special_Pork_Roast,
#  R_Nacho_Chicken,
#  R_Nancy_Black's_School_Brownies,
#  R_Nanny's_Oyster_Crackers,
#  R_Nantucket_Cranberry_Tart,
#  R_Navajo_Avocado_Rice,
#  R_Neoclassic_Chocolate_Mousse,
#  R_New_England_Chicken_Pot_Pie,
#  R_Nielsen_Massey&rsquo;s_Chocolate_Chip_Cookies,
#  R_Nif's_Tasty_Tuna_Salad_Muffins,
#  R_Ninja_Turtle_Pizzas,
#  R_No_Fry_Tortilla_Chips,
#  R_No_Nut_Trail_Mix,
#  R_Noah_Bedoahs_(Chocolate_Chip_Shortbread_Cookies),
#  R_Nordstrom_Lime_and_Chicken_Cilantro_Salad_Dressing,
#  R_North_State's_Plate's_Tofu_Roast,
#  R_Not_Justa_Nother_Potato_Salad,
#  R_Nutella_Bread_Pudding,
#  R_Oatmeal_Chocolate_Carmelitas,
#  R_Oatmeal_Chocolate_Chip_Cookies,
#  R_Oatmeal_Spice_Muffins,
#  R_Ojo_Domingo,
#  R_Oktoberfest_Pork_Roast,
#  R_Old_Fashioned_Caramel_Popcorn_in_the_Microwave!,
#  R_Old_Fashioned_Pot_Roast,
#  R_Old_Fashioned_Red_Velvet_Cake,
#  R_Old_Fashioned_Spicy_Oatmeal_Raisin_Bars,
#  R_Old_Stone_House_B&amp;B_Scones_(Ireland),
#  R_Olive_Garden_Spaghettini_With_Tuna,
#  R_Olive_Garden_Toscana_Soup,
#  R_On_the_Go_Snack_Mix,
#  R_One_Dish_Spicy_Pork_for_Two,
#  R_Onion_Roasted_Potatoes,
#  R_Onion_and_Chive_Pitas,
#  R_Ooey_Gooey_Brownies,
#  R_Orange_Crush_Chicken_for_the_Crock_Pot,
#  R_Orange_Flavored_Chicken,
#  R_Orange_Jello_Salad,
#  R_Orange_Kissed_Hot_Chocolate,
#  R_Orange_Pork_Stir_Fry_With_Broccoli_in_Lime_Butter,
#  R_Orange_Sesame_Kale_(Eat_for_Health),
#  R_Orange_Upside_Down_French_Toast,
#  R_Orange_and_Poppy_Seed_Quick_Bread,
#  R_Oven_Baked_Ribs,
#  R_Oven_Dried_Tasty_Tomatoes,
#  R_Oven_Fried_Catfish_Nuggets,
#  R_Oven_Roasted_Green_Beans,
#  R_Oven_Roasted_Tomato_and_Chevre_Bruschetta,
#  R_Oxtail_Bourguignonne,
#  R_Pafect_Tuna_Sandwich,
#  R_Pama_and_Circumstance,
#  R_Pan_Fried_Steaks_with_Balsamic_Glaze,
#  R_Panera_Mac_&amp;_Cheese,
#  R_Papaya_Canapes,
#  R_Parker_House_Rolls_(Made_by_Hand),
#  R_Parmesan_Popovers,
#  R_Parmesan_Potato_Wedges,
#  R_Passionate_White_Sangria,
#  R_Passover_Nut_Cookies,
#  R_Pasta_Cakes_with_Broccoli,
#  R_Pasta_Salad,
#  R_Pastitsio,
#  R_Paul_Prudhomme's_Cajun_Sauce_for_Beef,
#  R_Pavlova___from_Edmonds_Classics:_New_Zealander's_Favourite_Recip,
#  R_Peach_Sunrise,
#  R_Peanut_Butter_Cookie_Bars,
#  R_Peanut_Butter_Cream_Topped_Brownies,
#  R_Peanut_Butter_Crunch_Squares,
#  R_Peanut_Butter_Energy_Balls,
#  R_Peanut_Butter_and_Banana_S'mores,
#  R_Pear_Cream_Breakfast_Cake,
#  R_Pecan_Broccoli,
#  R_Pecan_Broccoli_Salad,
#  R_Pecan_Crusted_Honey_Chicken,
#  R_Penne_Ala_Vodka,
#  R_Pepper_Jack_Puffs,
#  R_Pepperoni_Rigatoni_Bake,
#  R_Perfect_Apple_Pie,
#  R_Perfect_Baked_Potato,
#  R_Perfect_Pasta,_Pesto,_and_Beans,
#  R_Persian_Flatbreads,
#  R_Pesto,
#  R_Pesto___Marcella_Hazan,
#  R_Pierogie_Casserole,
#  R_Pigs_and_Potatoes,
#  R_Pilaf_With_Peas_and_Raisins,
#  R_Pilgrim_Diner_Hawaiian_Chicken,
#  R_Pina_Colada_Pudding_Cups_(Low_Fat),
#  R_Pineapple_Crisp,
#  R_Pineapple_Muffins,
#  R_Pineapple_and_Cheddar_Cornbread,
#  R_Pirate's_Pantry_Ramos_Gin_Fizz,
#  R_Pizza_Casserole,
#  R_Pizza_Crust_(Gluten_Free),
#  R_Pizza_Party_Dip,
#  R_Pizza_Possibilites,
#  R_Plum_Ketchup,
#  R_Pocket_Pizza_Dough,
#  R_Pointless_Potatoes,
#  R_Polenta_Toasties_With_Mushroom_Sauce,
#  R_Pollo_Alla_Toscana,
#  R_Pomegranate_Blueberry_Freeze,
#  R_Pomegranate_Glazed_Chicken,
#  R_Pomegranate_and_Avocado_Dip,
#  R_Poor_Boy_Burgers,
#  R_Pork_Tenderloin_Medallions_With_Fresh_Figs,
#  R_Pork_in_Lime_Cream_Sauce,
#  R_Potato_Ham_Bake,
#  R_Potato_Pasta_and_Herb_Sauce_from_Kazahstan,
#  R_Potato_Salad_With_Sour_Cream_and_Bacon,
#  R_Potato_Stuffed_Portobellos_#5FIX,
#  R_Potato_topped_Casserole,
#  R_Potted_Stilton,
#  R_Protein_Pumpkin_Muffins,
#  R_Pucker_up_Smoothie,
#  R_Pumpkin_Dump_Cake!,
#  R_Pumpkin_Pineapple_Smoothie,
#  R_Pumpkin_Spice_Bars,
#  R_Pumpkin_Spiced_White_Hot_Chocolate,
#  R_Pumpkin_Wild_Rice_Soup,
#  R_Purse_Cake,
#  R_Quick_Hunan_Grilled_Chicken,
#  R_Quick_Pasta_Salad,
#  R_Quick_Tomato_Alphabet_Soup,
#  R_Quick_and_Easy_Mediterranean_Pizza,
#  R_Quick_and_Easy_Mexican_Casserole,
#  R_Quick_and_Light_Chicken_Paprikash,
#  R_Ragout_Of_Veal_With_Mushrooms_Marsala,
#  R_Rare_Beef_Vietnamese_Style,
#  R_Raspberry_Bars,
#  R_Raspberry_Cheese_Pie,
#  R_Raspberry_Salad,
#  R_Ratatouille,
#  R_Really_Crispy_Spicy_Cajun_Fried_Chicken,
#  R_Really_Fresh_Salsa_Mexicano,
#  R_Red_Chicken_Enchiladas,
#  R_Red_Lentil_and_Chorizo_Soup,
#  R_Red_Pork_Curry,
#  R_Red_Rice,
#  R_Red_Rocker_Margarita_Chicken_Sandwiches,
#  R_Red_Velvet_Pudding_Cake,
#  R_Refreshing_Peach_Bellini,
#  R_Rhubarb_Strawberry_Crumb_Pie,
#  R_Rhubarb_Strawberry_Ice_Cream,
#  R_Rib_Eye_Steaks_With_Fragrant_Chile_Rub_and_Salsa_Butter,
#  R_Rich_Fat_Free_Chocolate_Fudge_Sauce,
#  R_Ridiculously_Easy,_Utterly_Delicious_Egg_Sandwich,
#  R_Roast_Chicken_Chinese_Style,
#  R_Roast_pork_with_Figs_Onions_and_Marsala,
#  R_Roasted_Asparagus,
#  R_Roasted_Parsnips,
#  R_Roasted_Pumpkin_and_Sweet_Potato_Pilau,
#  R_Roasted_Winter_Vegetables_With_Cheesy_Polenta,
#  R_Roasted_Zucchini_and_Yellow_Squash,
#  R_Rocky_Road_Delight,
#  R_Rum_Runner_Martini,
#  R_Rum_Velvet_Coffee,
#  R_Russian_Black_Bread_(For_the_Bread_Machine),
#  R_SVESTKOVE_KNEDLIKY_(Plum_Dumplings),
#  R_Salade_De_Riz_Madame_Bequette(French_Rice_Salad),
#  R_Salmon_Cakes,
#  R_Salmon_Club_Sandwich,
#  R_Salmon_With_Chili_honey_Glaze,
#  R_Salmon_or_Tuna_Noodles_for_Two,
#  R_Salsa,
#  R_Sarah_McLachlan's_Asparagus_Frittata,
#  R_Saucepan_Spaghetti,
#  R_Sausage,_Potatoes,_and_Green_Bean_Toss_&amp;_Bake,
#  R_Sauteed_Yellow_Squash,_Zucchini_and_Roasted_Red_Peppers,
#  R_Savory_Stuffed_Chicken_Breasts_(Seasoned_Cream_Cheese_Stuffing),
#  R_Scalloped_Chicken,
#  R_Scalloped_Potatoes_(No_Dairy!),
#  R_Scalloped_Potatoes_With_Three_Cheeses,
#  R_Scallops_Charleston_Style,
#  R_Scratch_Lemon_Drink,
#  R_Seafood_Fondue,
#  R_Seared_Scallops_With_White_Beans_and_Bacon,
#  R_Sesame_Crusted_Trout_With_Ginger_Scallion_Salad,
#  R_Sesame_Green_Salad,
#  R_Sesame_Pita_Crisps,
#  R_Shipwreck,
#  R_Shredded_Herbed_Brussels_Sprouts,
#  R_Shrimp_Alfredo_Extraordinaire,
#  R_Shrimp_Melts,
#  R_Shrimp_Patricio,_Shrimp_Vesuvio,_Shrimp_Romano,
#  R_Shrimp_Scampi,
#  R_Shrimp_and_Kamaboko_Tempura,
#  R_Shrimp_and_Sausage_Kabobs,
#  R_Shrimp_with_Honey_Cream_Sauce,
#  R_Sicilian_Scampi_(olive_Garden_Style),
#  R_Silverbeet_(Swiss_Chard_)_Pie___Aka__&quot;_Grass_Pie&quot;,
#  R_Simple_Chocolate_Iced_Coffee,
#  R_Simple_Cinnamon_Apples,
#  R_Simple_Crock_Pot_Spicy_&amp;_Sweet_Sausage_Sandwich,
#  R_Simply_Strawberries,
#  R_Sin_Pie,
#  R_Skillet_Macaroni_and_Tvp_Beef_(Vegan),
#  R_Skinny_Pizza,
#  R_Skinny_Strawberry_Balsamic_Delight,
#  R_Slow_Cooker_3_Amigos_Chili,
#  R_Slow_Cooker_Cheese_Potatoes,
#  R_Slow_Cooker_Moroccan_Chicken,
#  R_Smashed_Peas_&_Ricotta_Cheese,
#  R_Smoked_Mozzarella_and_Greens_Penne,
#  R_Smoked_Salmon_Scramble,
#  R_Smoked_Salmon_Spread,
#  R_Smoked_Trout,_Lemon_&amp;_Fennel_Pasta,
#  R_Smoked_Whitefish_Salad,
#  R_Snicker_Salad,
#  R_Snickers_Salad,
#  R_Snowball_Suprises,
#  R_So_There_Reese's_Peanut_Butter_Bars,
#  R_Soooo_Good_Smoothie,
#  R_Soupy_Black_Beans,
#  R_Sour_Cream_Cornbread,
#  R_Sourdough_Gingerbread_Muffins,
#  R_South_West_Marinade,
#  R_Southern_Chicken_Pot_Pie,
#  R_Southwest_Bean_Soup,
#  R_Southwestern_Beef_Chili_With_Corn,
#  R_Southwestern_Burger,
#  R_Southwestern_Tofu_Wraps,
#  R_Spaghetti_Al_Pomodoro_(Spaghetti_With_Tomato_Sauce),
#  R_Spaghetti_Bolognese,
#  R_Spam&copy;_and_Vegetable_Hash,
#  R_Spanish_Chicken,_Rice_&_Sausage,
#  R_Spanokorizo_(Spinach_and_Rice_Casserole),
#  R_Spelt_Pizza_Crust,
#  R_Spice,_a_Cocktail,
#  R_Spicy_Beef_&_Zucchini_Soup,
#  R_Spicy_Black_Bean,_Green_Chili_&amp;_Cheese_Enchiladas,
#  R_Spicy_Chicken_Shawarma,
#  R_Spicy_Country_Ribs,
#  R_Spicy_Fried_Corn_and_Sausage_Casserole,
#  R_Spicy_Garlic_Kale_With_Sauteed_Red_Peppers,
#  R_Spicy_Jalapeno_Spread,
#  R_Spicy_Lemon_Chicken,
#  R_Spicy_Lentil_Burgers,
#  R_Spicy_Mexican_Chocolate_Ice_Cream,
#  R_Spicy_Peanut_Yogurt_Dip,
#  R_Spicy_Ranch_Chicken_Wings,
#  R_Spicy_Shrimp_and_Chorizo_Kebabs,
#  R_Spicy_Sicilian_Pasta_Toss,
#  R_Spinach_Artichoke_Dip,
#  R_Spinach_Crowns_With_Sesame_Dressing,
#  R_Spinach_Orzo_Pie,
#  R_Spinach_Salad_With_Raspberry_Dressing,
#  R_Spinach_Saute_With_Garlic_and_Parmesan_Cheese,
#  R_Spinach_Side_Salad,
#  R_Spinach_Stuffed_Portobello_Mushrooms,
#  R_Spinach_and_Potato_Casserole_W__Feta_Cheese,
#  R_Starry_Night_Taco_Cups,
#  R_Steak_Au_Poivre_Vert,
#  R_Steak_Salad_With_Spicy_Garlic_Salsa,
#  R_Steak_Teriyaki,
#  R_Steph's_Chicken_Fried_Brown_Rice,
#  R_Steph's_Sweet_Deli_Rolls,
#  R_Stew_Delight,
#  R_Stir_Fried_Cellophane_Noodles,
#  R_Stove_Top_Clambake,
#  R_Stracciatella_Gelato,
#  R_Strawberry_&amp;_Bleu_Cheese_Salad,
#  R_Strawberry_(Or_Banana_or_Peach__or_Pineapple)_Frozen_Daiquiris,
#  R_Strawberry_Banana_Shakes,
#  R_Strawberry_Crisps,
#  R_Strawberry_Lemonade_Cupcakes,
#  R_Strawberry_Oat_Muffins,
#  R_Strawberry_Shortcakes,
#  R_Strawberry_Soup,
#  R_Strawberry_Sourdough_Bread,
#  R_Strawberry_Spinach_Salad_with_Balsamic_Vinaigrette,
#  R_Strawberry_Tabbouleh,
#  R_Struffoli_(Honey_Balls),
#  R_Stuffed__Strawberry_Muffins,
#  R_Sugar_'n'_Spice_Pork_Tenderloin_from_the_James_Beard_House,
#  R_Sugar_Cookies,
#  R_Summer_Blueberry_Trifle,
#  R_Summer_Squash_Casserole,
#  R_Sun_Dried_Tomato_Tortellini_Soup,
#  R_Sunday_Garlic_Roast_Beef,
#  R_Super_Duper_Deviled_Eggs,
#  R_Super_Easy_Lo_Mein,
#  R_Super_Healthy_Grain_Breakfast,
#  R_Surillitos_De_Maiz_(Puerto_Rican_Cornmeal_Sticks),
#  R_Swedish_Oatmeal_Drops,
#  R_Swedish_Pancakes_With_Lingonberry_Butter,
#  R_Sweet_&_Sour_Beets,
#  R_Sweet_Potato_Cakes_With__Tomato_&amp;_Soy_Sauce,
#  R_Sweet_Potato_Fritters_With_Lemon_Chicken,
#  R_Sweet_Rice_Cakes,
#  R_Sweet_Rolls,
#  R_Sweet_Thing,
#  R_Sweet_and_Sour_Cucumber_Salad,
#  R_Swiss_Cheese_Fondue,
#  R_Swiss_French_Toast___Fotzel,
#  R_Swope_Bread,
#  R_Syltkokosrutor_(Finnish_Jam_and_Coconut_Squares),
#  R_Szechuan_Vegetable_Stir_Fry,
#  R_Taco_Noodle_Dish,
#  R_Tandoori_Naan_Bruschetta,
#  R_Tangy_Salisbury_Steaks,
#  R_Tasty_Crock_Pot_BBQ_Country_Style_Pork_Ribs,
#  R_Tasty_Green_Bean_Casserole_Cups,
#  R_Tender_Crock_Pot_Brisket,
#  R_Teriyaki_Hamburgers,
#  R_Texas_Bean_Bake,
#  R_Texas_Caviar_Party_Salsa,
#  R_Thai_Barbecue_Chicken_W__Spicy_Dipping_Sauce,
#  R_Thai_Barbecued_Chicken,
#  R_Thai_Cole_Slaw_Salad_and_Dressing,
#  R_Thai_Shrimp_Kabobs_With_Hot_Ginger_Sauce,
#  R_Thai_Tofu_With_Zucchini,_Red_Bell_Pepper_and_Lime,
#  R_The_Best_Salad_We_Ever_Ate!,
#  R_The_Everything_Muffins,
#  R_The_Joan_Farley__Sandwich,
#  R_The_Shepherd_Found_Another_Pie,
#  R_The_Sopranos'_Marinara_Sauce,
#  R_Thick_Pepperoni_Pizza_Casserole,
#  R_Thick_and_Chewy_Granola_Bars,
#  R_Three_Ingredient_Lemon_Cream,
#  R_Thundaai_(U_Roll_the_Tongue_While_Pronouncing_the_&quot;th&quot;,
#  R_Tilapia_Roll_With_Saute_Mushroom_Stuffing_#RSC,
#  R_Tilapia_With_Mayonnaise_and_Parmesan_Cheese,
#  R_Tilapia_in_Thai_Sauce,
#  R_Tillamook_Beer_Cheese_Soup,
#  R_Tim's_Louis_Salad,
#  R_Tofu_Chocolate_&quot;ice_Cream&quot;,
#  R_Tofu_With_Spinach,
#  R_Tokyo_Side_Car,
#  R_Tomatillo_Chicken_Tacos,
#  R_Tomato,_Cucumber,_and_Green_Pepper_Chopped_Salad,
#  R_Tomato_'n'_Cheese_Pasta,
#  R_Tomato_Croque_Monsieur,
#  R_Tomato_Curry_Sauce,
#  R_Tomato_Stuffed_Chicken_Rolls,
#  R_Tomato_Thyme_Quiche,
#  R_Tonys_Awesome_Creamy_Apricot_Chicken,
#  R_Tortellini_Salad_and_Basil_Dressing,
#  R_Tortilla_Pinwheels,
#  R_Toucan_Sam,
#  R_Tournedos_Brennan,
#  R_Triple_Vanilla_Bean_Cookies,
#  R_Tuna_Pasta_Puttanesca,
#  R_Tuna_Salsa_Wraps,
#  R_Turkey,_Wild_Rice_and_Cranberry_Salad,
#  R_Turkey_Cutlets_With_Lemon_Sauce,
#  R_Turkey_Pot_Pie_With_Stuffing_Crust_(Using_Leftovers),
#  R_Turkey_Verde,
#  R_Tuscan_Roasted_Chicken,
#  R_Twice_Baked_Squash,
#  R_Two_Berry_Crisp_With_Pecan_Streusel_Topping,
#  R_Ukranian_Poppy_Seed_Cake,
#  R_Ultimate_Fudge_Cake,
#  R_Ultimate_Suntan,
#  R_Unfried_Rice,
#  R_Unusual_Avocado_Salad,
#  R_Upside_Down_Sausage_and_Mushroom_Pizza,
#  R_Veal_Chops_with_Balsamic_Syrup,
#  R_Vegan_Chocolate_Chip_Bars,
#  R_Vegan_Spanakopita,
#  R_Vegetable_Pizza_Topping,
#  R_Vegetarian_Enchiladas,
#  R_Vegetarian_Sloppy_Joes,
#  R_Veggie_Beef_Stir_Fry,
#  R_Veggie_Lasagna,
#  R_Velvet_Chocolate_Sauce,
#  R_Versatile_Fresh_Vegetables_and_Cheese,
#  R_Very_Berry_Iced_Tea,
#  R_Very_Blueberry_Cheesecake,
#  R_Vichyssoise_(Potato_Leek_Soup),
#  R_Vodka_Scallops_With_Seasoned_Chipotle_and_Shallots,
#  R_Waist_Watcher_Chocolate_Banana_&quot;shake&quot;,
#  R_Walnut_Pie_Crust_Recipe,
#  R_Warm_Apple_and_Goat_Cheese_Salad,
#  R_Warm_Asparagus_Mushroom_Salad_with_Goat_Cheese_&_Balsamic_Dressi,
#  R_Warm_Caramel_Apple_Cake,
#  R_Warm_Cheddar_Vidalia_Onion_Dip,
#  R_Warm_Garlicky_Grape_Tomatoes,
#  R_Watermelon,_Cherry_Tomato,_Red_Onion_and_Cucumber_Salad,
#  R_Wd_Shrimp_With_Cheseapeake_Dipping_Sauce,
#  R_Weight_Watchers_Crock_Pot_French_Onion_Soup,
#  R_Weight_Watchers_Sour_Cream_Sugar_Cookies,
#  R_Weight_Watchers_Veggie_Barley_Soup_(1_Pt._for_1_Cup),
#  R_Weight_Watchers_Zucchini_Salad,
#  R_Whiskey_Pepper_Grilled_Steak,
#  R_Whisky_Oranges_With_Honey_Cream,
#  R_White_Brownies,
#  R_White_Cheddar_Potato_Gratin,
#  R_White_Chocolate_Mocha_Supreme,
#  R_White_Chocolate_and_Cranberry_Cookies,
#  R_White_Sauce_(Gluten_&_Dairy_free),
#  R_Whole_Wheat_Breakfast_Muffins,
#  R_Wholesome_Oat_Muffins_(Sbd_Phase_II),
#  R_Wild_Mango_and_Mustard_Seed_Salad,
#  R_Wild_Rice_With_Mushrooms,
#  R_William_Sonoma's_Grilled_Fontina_Sandwiches_With_Prosciutto_and,
#  R_Wilmington_Island_Marsh_Mud_Cake,
#  R_Wind_River_Mountain_Muesli,
#  R_Winter_Night_Creamy_Clam_Chowder,
#  R_Wisconsin_Broccoli_Cheddar_Cheese_Soup,
#  R_Wonderful_Smokey_Oven_Barbecued_Brisket,
#  R_Ww_3_Points___Vegetarian_Spring_Rolls,
#  R_Ww_Chocolate_Chip_Cookie_Bars,
#  R_Ww_Curried_Butternut_Squash_Soup,
#  R_Ww_Hot_Cocoa,
#  R_X_Rated,
#  R_Yorkshire_Pudding,
#  R_Yummy_Baked_Mac_&amp;_Cheese,
#  R_Yummy_Corn_Cakes,
#  R_Yummy_Easy_Cheesy_Ball,
#  R_Yummy_Lemon_Pie,
#  R_Zack's_Sweet_Sweet_Chocolate_Smoothie,
#  R_Zesty_Potatoes_With_Sour_Cream_&amp;_Chives,
#  R_Zesty_Roasted_Vegetables,
#  R_Ziti,_Eggplant_and_Fontina_Gratin,
#  R_Zucchini_Stuffed_Chicken_Breast,
#  R_Zucchini_and_Chickpea_Pancakes,
#  R_Zucchini_with_Cumin_and_Coriander,
#  R_ham_hock_gumbo]

# %%
# The problem is solved using PuLP's choice of Solver
prob.solve()
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/lolitalolita/opt/anaconda3/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/j9/7y5q0v6x4p3f2fdr5f5ffl0m0000gn/T/89b9a5596a8649c88be73721462bc056-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/j9/7y5q0v6x4p3f2fdr5f5ffl0m0000gn/T/89b9a5596a8649c88be73721462bc056-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 13 COLUMNS
# At line 8490 RHS
# At line 8499 BOUNDS
# At line 8500 ENDATA
# Problem MODEL has 8 rows, 993 columns and 7498 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 7 (-1) rows, 989 (-4) columns and 6501 (-997) elements
# 0  Obj 0 Primal inf 304.32181 (3)
# 3  Obj 2.7512142e-16
# Optimal - objective value 0
# After Postsolve, objective 0, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
# 1

# %%
# The status of thesolution is printed to the screen
print("Status:", LpStatus[prob.status])
# Out:
# Status: Optimal

# %%
# Each of the variables is printed with it's resolved optimum value
    
for v in prob.variables():
    if v.varValue>0:
        print(v.name, "=", v.varValue)
# Out:
# R_Coffee_for_the_Damned = 2.0890708
# R_Danish_Coffee = 34.488914
# R_Grilled_Cajun_Chicken = 0.66225166
# R_Spelt_Pizza_Crust = 273.06651

# %%
# The optimised objective function value is printed to the screen
print("Minimal sugar intake = ", value(prob.objective))
# Out:
# Minimal sugar intake =  0.0
