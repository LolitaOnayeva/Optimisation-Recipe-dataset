# %%
import pandas as pd
import numpy as np
import csv
from pathlib import Path 
import re
import string

# %%
df= pd.read_csv(r'/Users/lolitalolita/Downloads/recipes.csv')

# %%
df
# Out:
#        RecipeId                                        Name  RecipeCategory  \
# 0         46085                 Crock Pot Baked Potato Soup   One Dish Meal
# 1         93832  Frittata Di Spaghetti (spaghetti Frittata)       Breakfast
# 2         36034                  Berries With Italian Cream         Dessert
# 3        329988  Pork Tenderloin Medallions With Fresh Figs       < 15 Mins
# 4         59886   Kaseropita (Tiropita Using Kaseri Cheese)     Savory Pies
# ...         ...                                         ...             ...
# 43087     22945                              Yummy Meatloaf            Meat
# 43088    110033                          Slow Cooker Shanks      Lamb/Sheep
# 43089    240945                    Sin-Free Chocolate Chews    Drop Cookies
# 43090    164157                      Montreal Salsa Chicken  Chicken Breast
# 43091    226759                  Skinny Green Chili Chicken  Chicken Breast
#
#        Calories  CholesterolContent  CarbohydrateContent  SugarContent  \
# 0         699.8               137.3                 46.1           1.4
# 1         297.1               191.8                 11.7           0.7
# 2         131.9                23.3                 10.3           4.4
# 3         203.0                74.8                  1.5           0.6
# 4         261.6               103.6                 20.9           0.2
# ...         ...                 ...                  ...           ...
# 43087     281.5               111.3                 13.2          11.1
# 43088     697.2               242.1                  3.8           1.9
# 43089      94.5                 0.0                 22.7          19.1
# 43090     207.1                72.6                 20.1          12.7
# 43091     296.4                47.4                 24.4           3.9
#
#        ProteinContent  RecipeServings  HighScore
# 0                20.9               6          1
# 1                12.2               8          1
# 2                 9.1               6          0
# 3                23.3               4          1
# 4                 6.7              15          1
# ...               ...             ...        ...
# 43087            25.3               6          1
# 43088            72.9               4          0
# 43089             2.0              14          1
# 43090            24.9               4          1
# 43091            15.2               3          1
#
# [43092 rows x 10 columns]

# %%
# Get first 5000 recipes 
df=df[:5000]

# %%
# Get calories and content per one serving
df_per_serving=df[['Calories','CholesterolContent','CarbohydrateContent','SugarContent','ProteinContent']].div(df.RecipeServings, axis=0)

# %%
df_per_serving
# Out:
#         Calories  CholesterolContent  CarbohydrateContent  SugarContent  \
# 0     116.633333           22.883333             7.683333      0.233333
# 1      37.137500           23.975000             1.462500      0.087500
# 2      21.983333            3.883333             1.716667      0.733333
# 3      50.750000           18.700000             0.375000      0.150000
# 4      17.440000            6.906667             1.393333      0.013333
# ...          ...                 ...                  ...           ...
# 4995   27.275000            1.900000             1.300000      0.250000
# 4996    2.191667            0.000000             0.483333      0.191667
# 4997   68.512500            6.612500            12.987500      6.887500
# 4998  107.700000            0.000000            15.333333      4.233333
# 4999  132.916667           39.666667             5.033333      2.483333
#
#       ProteinContent
# 0           3.483333
# 1           1.525000
# 2           1.516667
# 3           5.825000
# 4           0.446667
# ...              ...
# 4995        0.400000
# 4996        0.100000
# 4997        1.337500
# 4998        2.400000
# 4999        2.166667
#
# [5000 rows x 5 columns]

# %%
# Import PuLP modeler functions
from pulp import *

# %%
# Create the 'prob' variable to contain the problem data
prob = LpProblem("Minimal_cholesterol_intake", LpMinimize)
# Out:
# /Users/lolitalolita/opt/anaconda3/lib/python3.9/site-packages/pulp/pulp.py:1352: UserWarning: Spaces are not permitted in the name. Converted to '_'
#   warnings.warn("Spaces are not permitted in the name. Converted to '_'")

# %%
Name_dict = list(df['Name'])

Calories_dict = dict(zip(Name_dict, df_per_serving['Calories']))
CholesterolContent_dict = dict(zip(Name_dict , df_per_serving['CholesterolContent']))
CarbohydrateContent_dict = dict(zip(Name_dict , df_per_serving['CarbohydrateContent']))
SugarContent_dict = dict(zip(Name_dict, df_per_serving['SugarContent']))
ProteinContent_dict = dict(zip(Name_dict, df_per_serving['ProteinContent']))

# %%
len(Name_dict)
# Out:
# 5000

# %%
# A dictionary called 'ingredient_vars' is created to contain the referenced Variables
recipe_name_vars = LpVariable.dicts("R", Name_dict, 0)

# %%
# The objective function is added to 'prob' first
prob += (
    lpSum([CholesterolContent_dict[i] * recipe_name_vars[i] for i in Name_dict]),
    "Total sugar content per dish",)

# %%
# The constraints are added to 'prob'
 

prob += (
    lpSum([Calories_dict[i] * recipe_name_vars[i] for i in Name_dict]) <= 2000.0,
    "Calories_dict_Requirement_max",
)
prob += (
    lpSum([Calories_dict[i] * recipe_name_vars[i] for i in Name_dict]) >= 1500.0,
    "Calories_dict_Requirement_min",
)


prob += (
    lpSum([SugarContent_dict[i] * recipe_name_vars[i] for i in Name_dict]) <= 30.0,
    "SugarContent_Requirement_max",
)
prob += (
    lpSum([SugarContent_dict[i] * recipe_name_vars[i] for i in Name_dict]) >= 5.0,
    "SugarContent_Requirement_min",
)

prob += (
    lpSum([CarbohydrateContent_dict[i] * recipe_name_vars[i] for i in Name_dict]) <= 150.0,
    "CarbohydrateContent_Requirement_max",
)

prob += (
    lpSum([CarbohydrateContent_dict[i] * recipe_name_vars[i] for i in Name_dict]) >= 120.0,
    "CarbohydrateContent_Requirement_min",
)

prob += (
    lpSum([ProteinContent_dict[i] * recipe_name_vars[i] for i in Name_dict]) <= 112.0,
    "ProteinContent_Requirement_max",
)
prob += (
    lpSum([ProteinContent_dict[i] * recipe_name_vars[i] for i in Name_dict]) >= 70.0,
    "ProteinContent_Requirement_min",
)

# %%
# The problem data is written to an .lp file
prob.writeLP("RecipeModel.lp")
# Out:
# [R_"All_in_the_Kitchen"_Chili,
#  R_"Immoral"_Sandwich_Filling_(Loose_Meat),
#  R_"Jiffy"_Roasted_Corn_and_Jalapeno_Cornbread,
#  R_"Smells_Like_Sunday"_Chicken_Fricassee_With_Meatballs,
#  R_&quot;_Almost_&quot;_Dairy_Queen_Blizzard_Ice_Cream_Cake,
#  R_&quot;_Atkins_Friendly&quot;_Cheesecake,
#  R_&quot;_Drunken&quot;_Pork_Chops,
#  R_&quot;_No_Harm_Eggplant_Parm&quot;_Ww,
#  R_&quot;_Tastes_Like_Mounds_Bar_&quot;__Kahlua_Cake,
#  R_&quot;fooled_Me&quot;_Flourless_Peanut_Butter_Cookies,
#  R_&quot;sannich&quot;_in_Soup,
#  R_'Get_Up_&_Go'_Bars,
#  R_(Crock_Pot)_Chicken_Chili,
#  R_(Fake)_Crab_Stroganoff,
#  R_*s.w.o.c.*_Pie_Cookies,
#  R_100%_Whole_Wheat_Bread,_Plain_and_Simple_(No_Knead),
#  R_15_Minute_Chili_Cheeseburger_Skillet,
#  R_24_Hour_Copper_Pennies,
#  R_24_Hour_Lettuce_Salad,
#  R_2_Minute_Noodle_Corn_Pancakes,
#  R_3_Bean_Salad,
#  R_3_Cheese_Manicotti,
#  R_3_Dragon’s_Szechuan_Steak,
#  R_3_Layered_Mexican_Dip,
#  R_3_Minute_Bread_Pudding_in_a_Mug,
#  R_3_Peppercorn_Hazelnut_Soup,
#  R_3_Spice_Fuss_Free_Fish_Fillet_Curry,
#  R_4_Bean_Relish,
#  R_4_Cheese_Baked_Macaroni___Italian_Style,
#  R_50_Dollar_Salad,
#  R_5_Ingredient_Crescent_Roll_Breakfast_Bake,
#  R_5_Layer_Italian_Dip,
#  R_5_Minute,_No_Cook_Marinara_Sauce,
#  R_7_Layer_Punchbowl_Dessert,
#  R_7_Layer_Salad___Low_Fat_Version,
#  R_7_Minute_Rich_and_Creamy_Polenta,
#  R_8_for_$8___Broiled_BLT_Burgers_for_a_Bunch,
#  R_99_Bananas_and_a_Coconut_Cocktail,
#  R_A_Leg_up_(Oven_Fried_Drumsticks),
#  R_Aam_Lhassi,
#  R_Aaron_Tippin's_Mexican_Casserole,
#  R_Aarsi&rsquo;s_Ultimate_Valentine_Cake,
#  R_Absolutely_Perfect_Deviled_Eggs,
#  R_Acapulco_Golden_Burgers,
#  R_Acorn_Squash_Soup,
#  R_Addictive_Chocolate_Tapioca_Pudding,
#  R_Adult_Root_Beer_Float,
#  R_African_Style_Rice,
#  R_After_Thanksgiving_Turkey,_Sweet_Potato_and_Bacon_Chowder,
#  R_Agua_De_Mel&oacute;n,
#  R_Aish's_Grated_Potato_Kugel,
#  R_All_About_the_Heart_Salad,
#  R_All_American_Pancakes,
#  R_All_Chocolate_Blackout_Cake_from_Ebinger's,
#  R_All_Day_Slow_Cooker_Chicken,
#  R_All_Fruit__Popsicles_(Melons_and_Berries),
#  R_All_In_One_Magic_Non_Toxic_Bathroom_Cleaner,
#  R_All_Season_Peanut_&amp;_Corn_Suet_Bird_Treats,
#  R_Almond_Butter_Cookies,
#  R_Almond_Cookie_Cups,
#  R_Almond_Crusted_Chicken_Breast,
#  R_Almond_Crusted_Chicken_Fingers,
#  R_Almond_Fudge_Truffles,
#  R_Almond_Pancakes,
#  R_Almond_Shortbreads,
#  R_Almond_and_Plum_Tart,
#  R_Almost_Deerhead_Chili_Dogs,
#  R_Almost_Fried_Plantains___Virtually_Fat_Free,
#  R_Almost_Instant_Baked_Apple,
#  R_Aloha_Salmon,
#  R_Aloo_Ki_Tikiyan_(Vegan),
#  R_Alouette_Crumbled_Goat_Cheese_Ny_Grilled_Strip_Steak_Salad_of_Gr,
#  R_Alton_Brown's_White_Trash,
#  R_Amaretto_Balls,
#  R_Amazing_Apple_Pie,
#  R_Amazing_Baked_Lemon_Garlic_Chicken_Thighs_and_Potatoes,
#  R_Amazing_Chicken_Tortilla_Soup!,
#  R_Amazing_Sweet_Potato_Salad,
#  R_Amazon_Catfish,
#  R_Ambassade_D'auvergne's_Seven_Hour_Leg_of_Lamb,
#  R_American_Girl_Magazine's_Colorful_Cake,
#  R_Amish_Stewed_Crackers,
#  R_An_Oatmeal_Poached_Egg,
#  R_Angel_Food_Ice_Cream_Cake,
#  R_Angel_Hair_Pasta_With_Garden_Vegetables,
#  R_Angel_Hair_Pasta_With_Shrimp_and_Creamy_Lemon_Caper_Sauce,
#  R_Angel_Hair_Primavera,
#  R_Angel_Hair_with_Spicy_Eggplant_Sauce,
#  R_Angel_Kiss,
#  R_Ann's_Chicken_Oriental,
#  R_Ann's_Cranberry_Pear_Cake,
#  R_Ann's_Easy_Posole,
#  R_Annabel's_Homemade_Granola,
#  R_Annie's_Apple_Crisp,
#  R_Annie's_Turkey_Salad,
#  R_Annie,s_Potato_Dish,
#  R_Another_Rhubarb_Crunch,
#  R_Antipasto_Squares,
#  R_Ants_on_a_Log,
#  R_Anytime_Pizza_Casserole,
#  R_Apple,_Strawberry,_Banana_Smoothie,
#  R_Apple_Bread,
#  R_Apple_Bread_Pudding_(Pampered_Chef),
#  R_Apple_Cinnamon_Creme_Brulee,
#  R_Apple_Cinnamon_Oatmeal,
#  R_Apple_Cobbler,
#  R_Apple_Coleslaw,
#  R_Apple_Cranberry_Bread,
#  R_Apple_Cranberry_Mold,
#  R_Apple_Crisp,
#  R_Apple_Crisp_With_Organic_Sugar,
#  R_Apple_Flory____a_Puff_Pastry_Tart_(Scotland),
#  R_Apple_Glazed_Roast_Chicken_and_Rice,
#  R_Apple_Granola_Bread,
#  R_Apple_Gruyere_French_Toast_With_Red_Onion,
#  R_Apple_Oat_Snack_Squares,
#  R_Apple_Orchard_Cookies,
#  R_Apple_Oven_Pancake,
#  R_Apple_Pie_Cookies,
#  R_Apple_Pie_Martini,
#  R_Apple_Romaine_Salad,
#  R_Apple_Sauce_Pancakes,
#  R_Apple_Skewers,
#  R_Apple_Strawberry_Rhubarb_Crisp,
#  R_Apple_Streusel_Cheesecake,
#  R_Apple_Stuffed_Tenderloin_With_Cinnamon_Raisin_Sauce,
#  R_Apple_Stuffing,
#  R_Apple_Upside_Down_Cake,
#  R_Apple_Wrap_Sandwich,
#  R_Apple_Zeppole_With_Cinnamon_Whipped_Cream,
#  R_Apple_and_Cheese_Snack,
#  R_Apple_and_Fennel_Roasted_Pork_Tenderloin,
#  R_Apple_and_Onion_Stuffing___Muffins,
#  R_Apple_and_Raisin_Crumble,
#  R_Apples_and_Ground_Beef_Pasta,
#  R_Applesauce_Oatmeal_Cake_With_Broiled_Coconut_Topping,
#  R_Applesauce_Streusel_Muffins,
#  R_Applescotch_Crisp,
#  R_Apricot,_Berry,_and_Jicama_Salad_with_Honey_lime_Dressing,
#  R_Apricot_Bars,
#  R_Apricot_Heaven,
#  R_Apricot_Mango_Martini,
#  R_Apricot_Nut_Bread,
#  R_Apricot_Plum_Sauce,
#  R_Apricot_Rosemary_Glazed_Pork_Loin,
#  R_Apricot_Teriyaki_Pork_Chops,
#  R_Aprikoosivoileipa____Hot_Apricot_Sandwich_(Finland),
#  R_Arabic_Almond_Milk,
#  R_Arabic_Cardamom_Shortbread_(Gorayba),
#  R_Arctic_Lemon_Freeze,
#  R_Arkansas_Corn_Bread,
#  R_Aromatic_Broccoli_and_Cauliflower_Salad,
#  R_Aromatic_Chicken_Curry,
#  R_Arroz_Con_Gandules,
#  R_Arroz_Con_Gandules_(Rice_and_Pigeon_Peas)_A_Puerto_Rican_Fav,
#  R_Artichoke,_Spinach_&amp;_Feta_Stuffed_Shells,
#  R_Artichoke_Bread,
#  R_Artichoke_Cheese_Balls,
#  R_Artichoke_Heart_and_Anchovy_Carbonara,
#  R_Artichoke_Spinach_Casserole,
#  R_Artichoke_Spinach_Dip,
#  R_Artichoke_Spinach_Frittata,
#  R_Artichoke_and_Bean_Salad,
#  R_Artichoke_and_Mushroom_Lasagna,
#  R_Artichokes_Gourmet,
#  R_Asian_Chicken,_Noodle_and_Vegetable_Salad,
#  R_Asian_Chicken_Ravioli_With_V8_Creamy_Tomato_Sauce,
#  R_Asian_Peanut_Noodles,
#  R_Asian_Ramen_Noodle_Soup,
#  R_Asian_Style_Vegetable_Slaw,
#  R_Asian_Sugar_Snap_Peas,
#  R_Asian_Turkey_or_Chicken_Salad_With_Mandarin_Balsamic_Vinaigrette,
#  R_Asian_Vegetable_Soup,
#  R_Asparagus,_Mushroom_and_Cheese_Omelet_With_Herbs,
#  R_Asparagus_Appetizer___Spear_Ecstasy,
#  R_Asparagus_Lasagna,
#  R_Asparagus_Omelet_W_Shrimp_Hollandaise_Sauce_(For_Andi),
#  R_Asparagus_Risotto,
#  R_Asparagus_Soup,
#  R_Asparagus_Tarts,
#  R_Asparagus_With_Gorgonzola,
#  R_Asparagus_With_Lemon_Caper_Vinaigrette,
#  R_Asparagus_and_Almond_Soup,
#  R_Asparagus_and_Parmesan_Quiche,
#  R_Atomic_Palm,
#  R_Aunt_Jemima_Cornbread,
#  R_Aunt_Jo's_Crescent_Chicken_Rolls,
#  R_Australian_Crab_and_Asparagus_Soup,
#  R_Austrian_Kaiserschmarren_With_Raisins_and_Plum_Jam,
#  R_Authentic_Beef_Chuck_Goulash,
#  R_Authentic_Carne_Asada,
#  R_Authentic_Chili_Verde_(Pork_and_Green_Tomatillo_Stew),
#  R_Authentic_Cornish_Pasties,
#  R_Authentic_Italian_Tomato_Sauce,
#  R_Authentic_Mexican_Tomato_Rice,
#  R_Authentic_Tex_Mexican_Enchiladas,
#  R_Avocado,_Sun_Dried_Tomato_and_Mozzarella_Stuffed_Chicken_Breast,
#  R_Avocado_Chicken_Salad_by_Paula_Deen,
#  R_Avocado_Crab_Enchiladas_with_Green_Sauce,
#  R_Avocado_Crabmeat_Sandwiches,
#  R_Avocado_Orange_Salsa,
#  R_Avocado_Paste_Sandwich,
#  R_Avocado_Pizza,
#  R_Avocado_Sandwich,
#  R_Avocado_Stuffed_Eggs,
#  R_Avocado_Toast,
#  R_Avocado_and_Egg_Salad,
#  R_Aw_Shucks_Grilled_Corn,
#  R_Awesome_Mashed_Potato_Casserole,
#  R_Azerbaijani_Pomegranate_and_Spinach_Soup_(Vegan),
#  R_BBQ_Crock_Pot_Beef,
#  R_BJ's_Restaurant_Parmesan_Crusted_Chicken,
#  R_BLT_Quesadillas,
#  R_BUSH's_Chili_Bean_Casserole,
#  R_B_L_T_Pizza,
#  R_Baby's_Bottom,
#  R_Baby's_Millionaire_Pie,
#  R_Bachelor_BBQ_Chicken,
#  R_Backyard_Potatoes,
#  R_Bacon_&_Cheddar_Quiche,
#  R_Bacon_BBQ_Burgers,
#  R_Bacon_Black_Beans,
#  R_Bacon_Cabbage_Stir_Fry,
#  R_Bacon_Cheddar_Chicken_Fillet_Melt,
#  R_Bacon_Macaroni_and_Cheese_(Cooking_Light),
#  R_Bacon_Potato_Salad,
#  R_Bacon_Pumpkin_and_Pesto_Pasta,
#  R_Bacon_Smothered_Green_Beans,
#  R_Bacon_Topped_Cheese_Potatoes,
#  R_Bacon_Wrapped,_Cream_Cheese_Stuffed_Chicken_Breasts,
#  R_Bacon_Wrapped_Breadsticks,
#  R_Bacon_Wrapped_Mini_Meatloaf,
#  R_Bacon_Wrapped_Pork_Medallions,
#  R_Bacon_and_Molasses_Beans,
#  R_Badam_Burfi_(Almond_Squares),
#  R_Bagel_Tuna_Melt,
#  R_Bahama_Breeze_Fire_Roasted_Jerk_Shrimp,
#  R_Bahama_Mama___Large_Batch,
#  R_Bailey's_Banana_Colada,
#  R_Baileys_Mint_Chocolate_Martini,
#  R_Baked_Acorn_Squash_&amp;_Brown_Sugar,
#  R_Baked_Acorn_Squash_With_Sherry_(Thanksgiving),
#  R_Baked_Acorn_or_Butternut_Squash_With_Orange_Garlic_&amp;_Parsley,
#  R_Baked_Apples_and_Cranberries,
#  R_Baked_Artichoke_Dip,
#  R_Baked_Banana_and_Coconut_Porridge,
#  R_Baked_Beans_1998,
#  R_Baked_Beans_Toast,
#  R_Baked_Beans_and_Hamburger_Casserole,
#  R_Baked_Beans_on_Toast_Au_Fromage,
#  R_Baked_Brie_Pastries_With_Artichoke_and_Prosciutto,
#  R_Baked_Broccoli,
#  R_Baked_Cabbage,
#  R_Baked_Caramel_Popcorn,
#  R_Baked_Cheese_Crepes___Giada_De_Laurentiis,
#  R_Baked_Cheese_Fiesta_Dip,
#  R_Baked_Cheese_Grits_Casserole,
#  R_Baked_Cheesecake,
#  R_Baked_Chicken,
#  R_Baked_Chicken_Tagliatelle_With_Mushrooms_and_Peppers,
#  R_Baked_Chicken_Tarragon,
#  R_Baked_Chicken_w__light_sauce,
#  R_Baked_Chickpea_Falafel,
#  R_Baked_Chili_Cheese_Macaroni,
#  R_Baked_Coconut_French_Toast_With_Tropical_Fruit_Compote,
#  R_Baked_Cod_Portuguese,
#  R_Baked_Corn_on_the_Cob,
#  R_Baked_Creamy_Chicken_and_Cornbread,
#  R_Baked_Creamy_Cinnamon_Pumpkin,
#  R_Baked_Cucumbers_With_Cauliflower,
#  R_Baked_Egg_Muffins,
#  R_Baked_Eggs_And_Ham_For_Two,
#  R_Baked_Fish_Fillets,
#  R_Baked_Flounder_Parmesan,
#  R_Baked_Flounder_With_Lemon,_Parsley_and_Bread_Crumbs,
#  R_Baked_Fruit_Compote,
#  R_Baked_Garlic_Chicken,
#  R_Baked_German_Pork_Chops,
#  R_Baked_Graham_Cracker_French_Toast,
#  R_Baked_Grouper_With_Sauteed_Vegetables,
#  R_Baked_Herb_Parmesan_Tilapia,
#  R_Baked_Herbed_Chicken_Nuggets,
#  R_Baked_Italian_Sausage__With_Potatoes_and_Rosemary,
#  R_Baked_Jacket_Potato_With_Baked_Beans_and_Cheese,
#  R_Baked_Macaroni_and_Cheese,
#  R_Baked_Manicotti,
#  R_Baked_Mushroom_Rice,
#  R_Baked_Mushroom_and_Cheese_Penne,
#  R_Baked_Palak_(Spinach)_and_Corn,
#  R_Baked_Parmesan_Breaded_Fish,
#  R_Baked_Pears_In_Caramel_Sauce,
#  R_Baked_Peppers_with_Ricotta_and_Basil,
#  R_Baked_Pork_Chops_With_Apples,
#  R_Baked_Pork_and_Apple_Meatballs_(Gary_Rhodes),
#  R_Baked_Potato_Soup,
#  R_Baked_Potatoes_and_Mushrooms,
#  R_Baked_Rice,
#  R_Baked_Rice_For_A_Crowd,
#  R_Baked_Salmon,
#  R_Baked_Snapper_With_Potatoes,_Oregano_and_White_Wine,
#  R_Baked_Spaghetti_Casserole,
#  R_Baked_Spaghetti_with_Chicken,
#  R_Baked_Spicy_Fries,
#  R_Baked_Squash_and_Parmesan_Cheese_Pudding_(Tortino_Di_Zucca),
#  R_Baked_Stuffed_Artichokes,
#  R_Baked_Stuffed_Polenta_(Polenta_Al_Forno),
#  R_Baked_Sweet_Potatoes_With_Apricots_and_Prunes,
#  R_Baked_Tortellini_With_Red_and_White_Clam_Sauce,
#  R_Baked_Turkey_Paleo_Meatballs,
#  R_Baked_Ziti,
#  R_Baked__Fish__Almondine,
#  R_Bakewell_Tart,
#  R_Bakinbaby's_Dashing_Albacore_Sandwich,
#  R_Baklava_Mini_Bites,
#  R_Balinese_Rice_Salad,
#  R_Balsamic_Braised_Chicken_With_Honey,
#  R_Balsamic_Chicken_With_Baby_Spinach,
#  R_Balsamic_Chicken_With_Red,_Orange_and_Yellow_Peppers,
#  R_Balsamic_Fried_Eggs_With_Wilted_Greens_(In_Under_10_Minutes),
#  R_Balsamic_Mashed_Sweet_Potatoes,
#  R_Balsamic_Onion_Tartlets,
#  R_Balsamic_Roast_Pork_Tenderloins,
#  R_Balsamic_Tossed_Pasta_With_Fresh_Tomato,_Arugula__and_Mozzarella,
#  R_Banana,_Pineapple_and_Coconut_Cake,
#  R_Banana_Apple_Smoothie,
#  R_Banana_Berry_Shake,
#  R_Banana_Cake_With_Brown_Sugar_Frosting,
#  R_Banana_Carob_Chocolate_Muffins,
#  R_Banana_Coconut_&quot;_Cream_Pie&quot;_Smoothie,
#  R_Banana_Coconut_Smoothie,
#  R_Banana_Cookies,
#  R_Banana_French_Toast,
#  R_Banana_Nut_Cheesecake,
#  R_Banana_Nut_Crunch_Muffins,
#  R_Banana_Nut_Muffins_(Sbd_Phase1),
#  R_Banana_Oat_Pancakes,
#  R_Banana_Pineapple_Cake,
#  R_Banana_Salsa,
#  R_Banana_Shake___Smoothie,
#  R_Banana_Smoothie,
#  R_Banana_Split_Pudding_Brownies,
#  R_Banana_Split_Shakes,
#  R_Banana_Split_Shot,
#  R_Banana_Sweet,
#  R_Banana_Walnut__vegan!__Yummy_Pancakes,
#  R_Bannock,
#  R_Barbecue_Chicken_Nachos,
#  R_Barbecue_Cups,
#  R_Barbecue_Pork_on_Buns,
#  R_Barbecue_Ranch_Dressing,
#  R_Barbecue_Sausage_Bites,
#  R_Barbecue_Shrimp,
#  R_Barbecued_Apricot_Hot_Dogs,
#  R_Barbecued_Chicken_Pot_Pie_(From_Cooking_Light),
#  R_Barbecued_Salmon,
#  R_Barley_Pilaf,
#  R_Barley_Water,
#  R_Barley_With_Chicken_and_Parmesan_Cheese___Canyon_Ranch_Resort,
#  R_Bars_of_Iron,
#  R_Basic_Boiled_Shrimp,
#  R_Basic_Cream_Scones,
#  R_Basic_Creamy_Cheese_Sauce,
#  R_Basic_Fat_Free_Gravy,
#  R_Basic_Italian_Eggplant_Stew,
#  R_Basic_White_Cake,
#  R_Basic_and_Simple_Shrimp_Salad,
#  R_Basil_Pesto,
#  R_Basquadillas,
#  R_Basque_Chicken_Casserole,
#  R_Batter_Fried_Fresh_Tomatoes,
#  R_Bavarian_Lentil_Soup,
#  R_Bavarian_Strawberry_Cream,
#  R_Bayerische_Semmelkl&ouml;sse,
#  R_Bayou__Salad,
#  R_Bb_King's_Catfish_Nuggets_&amp;_Sauce,
#  R_Bbq_Spareribs,
#  R_Bea's_Broccoli_Salad,
#  R_Bea's_Roasted_Red_Potatoes,
#  R_Bean,_Potato_and_Sauerkraut_Soup,
#  R_Bean_And_Tomato_Salad,
#  R_Bean_and_Corn_Casserole,
#  R_Beans,_Bow_Ties,_Spinach_&amp;_Cheese,
#  R_Beans_and_Beer,
#  R_Beans_and_Rice_With_Cumin_(_Crock_Pot_),
#  R_Bed_and_Breakfast_Sausage_&amp;_Egg_Casserole,
#  R_Beed_Mahshi___Egyptian_Deviled_Eggs,
#  R_Beef_Burgers_from_N_Z,
#  R_Beef_Casserole,
#  R_Beef_Cups,
#  R_Beef_Enchilada_Soup,
#  R_Beef_Fillet_in_Coconut,
#  R_Beef_Fillets_With_Portabella_Sauce,
#  R_Beef_Goulash,
#  R_Beef_Jerky,
#  R_Beef_Lo_Mein___Ww,
#  R_Beef_Paprika_Soup_and_Dumplings,
#  R_Beef_Pepper_Steak_For_Two,
#  R_Beef_Steaks_With_Capsicum_Relish,
#  R_Beef_Stew__Crock_Pot,
#  R_Beef_Stroganoff,
#  R_Beef_Stroganoff_................_Betty_Webb,
#  R_Beef_Taco_Bake,
#  R_Beef_Tenderloin_in_Wine_Sauce,
#  R_Beef_Teriyaki,
#  R_Beef_With_Broccoli,
#  R_Beef_and_Chorizo_Chili,
#  R_Beef_and_Corn_Tacos_With_Garlicky_Roasted_Peppers,
#  R_Beef_and_Mushroom_Sloppy_Joes,
#  R_Beef_and_Mushroom_topped_Potato_Wedges,
#  R_Beefy_Chicken_Loaf_(oamc),
#  R_Beefy_Layered_Burrito_Casserole,
#  R_Beer_Battered_Coconut_Shrimp_With_Pineapple_Mustard_Sauce,
#  R_Beer_Battered_Shrimp_With_Chipotle_Honey_Sauce,
#  R_Beer_Burgers,
#  R_Beer_Cheese_Fried_Potatoes,
#  R_Beer_Cheese_Soup_in_Bread_Bowls,
#  R_Beer_Meatballs,
#  R_Beet_Brownies,
#  R_Beet_Risotto_With_Goat_Cheese_and_Walnuts,
#  R_Beets_Buying_Bread_(A_B_M),
#  R_Bek's_Grilled_Tuna_Steaks_Glazed_With_Ginger,_Lime,_and_Soy_OAMC,
#  R_Belgian_Fries_With_Andalouse_Sauce,
#  R_Bell_Pepper,_Kidney_Beans,_and_Mushrooms,
#  R_Bell_Pepper_Hash,
#  R_Bermuda_Rum_Swizzle,
#  R_Berries_With_Italian_Cream,
#  R_Berries_in_Champagne_Jelly,
#  R_Berry_Berry_Good_Smoothie!,
#  R_Berry_Mascarpone_Christmas_Gateau,
#  R_Berry_Mint_Smoothie,
#  R_Berry_Pie,
#  R_Berry_Smoothie,
#  R_Berry_Summer_Pudding_from_Woman's_World_6_22_09,
#  R_Berry_Tossed_Salad,
#  R_Berry_Yummy_Bread_Pudding,
#  R_Berry__Green_Tea_Smoothie,
#  R_Best_Baked_Ziti,
#  R_Best_Brownies_With_Frosting,
#  R_Best_Ever_Fried_Rice,
#  R_Best_Ever_Fudge,
#  R_Best_Flan_Ever,
#  R_Best_Ham_and_Split_Pea_Soup,
#  R_Better_Blueberry_Muffins_(Shape_Magazine),
#  R_Better_Homes'_Cappuccino,
#  R_Better_Homes_and_Gardens_Apple_Bacon_Burger,
#  R_Better_Than_"out_of_the_box"_Macaroni_and_Cheese,
#  R_Better_Than_Caviar_Egg_Salad_Araby,
#  R_Better_Than_Sex_Cake__Weight_Watchers_Style,
#  R_Bibimbop,
#  R_Big_Boy's_Tartar_Sauce_Clone___Copycat,
#  R_Big_John's_Cajun_Fried_Oysters,
#  R_Big_Mac_Sauce_Low_Fat,
#  R_Big_Sausage_Rolls_for_Picnics___Lunch,
#  R_Big_Thick_Buttery_Roast_Beef_'n_Cheddar_Sammies___Sandwiches,
#  R_Bikini_Bottom_Seaweed_Pie_(Spinach_Really)_from_Sponge_Bob,
#  R_Bikini_Martini,
#  R_Bird_Nests,
#  R_Birthday_Cake_Martini,
#  R_Biscotti,
#  R_Biscotti_Di_Anise,
#  R_Biscuits_and_Asparagus_Casserole,
#  R_Bisquick_Chili_Relleno_Casserole,
#  R_Bisquick_Impossible_Quiche,
#  R_Bisquick_Sausage_Breakfast_Pie,
#  R_Bisquick_Tuna_Pie,
#  R_Bisquick_sour_cream_biscuits,
#  R_Bistro_Steak_Sandwich_With_Seasoned_Potato_Chips,
#  R_Bite_Size_Chocolate_Banana_Chip_Muffins,
#  R_Black_Bean,_Chicken__and_Corn_Soup_With_Toasted_Tortilla_Strips,
#  R_Black_Bean_&amp;_Corn_Salad,
#  R_Black_Bean_&amp;_Ground_Turkey_Burrito_Mix,
#  R_Black_Bean_Cakes_With_Chipotle_Cream,
#  R_Black_Bean_Hummus_(From_1001_Low_Fat_Vegetarian_Recipes),
#  R_Black_Bean_Salad,
#  R_Black_Bean_and_Soyrizo_Chili,
#  R_Black_Bottom_Cupcakes,
#  R_Black_Eyed_Peas_and_Collards,
#  R_Black_Jack_Martini,
#  R_Black_Raspberry_Margarita,
#  R_Black_Russian,
#  R_Blackberry_Margarita,
#  R_Blackberry_Sage_Thumbprint_Cookies,
#  R_Blackout_Baked_Alaska,
#  R_Blarney_Stone_Cake_With_Frosting!,
#  R_Blazing,_I_Mean_Braising_Pork_and_Red_Lentils,
#  R_Blizzard,
#  R_Bloody_Blast,
#  R_Bloody_Martini,
#  R_Bloody_Mary's_Party_Style,
#  R_Bloody_Mary_Cocktail,
#  R_Blue_Cheese,_Cranberry,_and_Walnut_Pinwheels,
#  R_Blue_Cheese_&amp;_Sun_Dried_Tomato_Dressing,
#  R_Blue_Cheese_Potato_Salad,
#  R_Blue_Cheese_Sauce_for_Steaks,_Burgers,_and_Chicken,
#  R_Blue_Cheese_Spaghetti,
#  R_Blue_Cheese_Spread,
#  R_Blue_Cheese_Stuffed_Hamburgers,
#  R_Blue_Corn_Feta_Taquitos,
#  R_Blue_Hawaii_(Smoothie),
#  R_Blue_Ribbon_Cheesecake,
#  R_Blue_and_Red_Berry_Smoothie,
#  R_Blueberries_and_Cream_Frappuccino,
#  R_Blueberry_Balsamic_Barbecue_Sauce,
#  R_Blueberry_Banana_Oatmeal_Pancakes,
#  R_Blueberry_Banana_Snack_Cakes,
#  R_Blueberry_Bird's_Nest_Strudel,
#  R_Blueberry_Cake,
#  R_Blueberry_Cobbler,
#  R_Blueberry_Cookies,
#  R_Blueberry_Cream_Cheese_Braided_Loaf,
#  R_Blueberry_Crunch_Cake_(Paula_Deen),
#  R_Blueberry_Grape_Salad,
#  R_Blueberry_Lemon_Muffins,
#  R_Blueberry_Lemon_Parfait,
#  R_Blueberry_Oat_Bran_Muffins,
#  R_Blueberry_Peach_Crumble,
#  R_Blueberry_Peach_Smoothie,
#  R_Blueberry_Pomegranate_Tarragon_Marinated_Pork_Chops,
#  R_Blueberry_Streusel_Muffins,
#  R_Blueberry__Streusel_Muffins_Weight_Watcher's_3_Points,
#  R_Blueberry_and_Raspberry_Pie,
#  R_Blueberry_and_Walnut_Oatmeal,
#  R_Bob_Evans_Style_Buttermilk_Biscuits,
#  R_Bobbo's_Fry_Sauce,
#  R_Bobby's_Goulash,
#  R_Bobby_Flay's_Quick_Saffron_Risotto_With_Roasted_Asparagus,
#  R_Bobotie,
#  R_Bohemian_Beef_Dinner,
#  R_Boiled_Peanuts,
#  R_Bojangles_Biscuits,
#  R_Bok_Bok_Popovers,
#  R_Boreal_Forest_Cranberry_Brownies,
#  R_Boston_Baked_Lentils,
#  R_Boston_Fenway_Franks,
#  R_Boston_Yellow_Squash_Casserole,
#  R_Boulangere_Potatoes_(Savoury_Potato_and_Onion_Bake),
#  R_Bourbon_Pecan_Pie,
#  R_Bourbon_Pecan_Pound_Cake,
#  R_Bourbon_Sweet_Potatoes,
#  R_Bow_Tie_Pasta_With_Broccoli_and_Tomatoes,
#  R_Boys_are_Stupid,
#  R_Brainless_Banana_Pancakes,
#  R_Braised_Beef_Liver,
#  R_Braised_Cabbage_Tanzanian,
#  R_Braised_Cannellini_Beans_With_Onions_and_Arugula,
#  R_Braised_Hoisin_Beer_Short_Ribs,
#  R_Braised_Lamb_Shank_Pie,
#  R_Braised_Lamb_Shanks,
#  R_Braised_Red_Cabbage,
#  R_Braised_Red_Cabbage,_Apples,_and_Brats,
#  R_Braised_Red_Cabbage_(Choux_Rouges_Brais&eacute;s),
#  R_Braised_Salmon,
#  R_Braised_Short_Ribs_With_a_Red_Wine_Reduction,
#  R_Bran_Date_Bread,
#  R_Brandied_Beef_Stew,
#  R_Brandied_Tomato_Sauce_(Flambe'),
#  R_Brats__Our_Style,
#  R_Bratten's_Clam_Chowder___Copycat,
#  R_Brazilian_Cornbread_(_Bread_Machine_),
#  R_Brazo_De_Mercedes___Creme_filled_Log_Cake,
#  R_Bread,_Apple,_Raisin_Dressing_for_Turkey,
#  R_Bread_Machine_Conchas,
#  R_Breaded_Ravioli,
#  R_Breakfast_Bagel_Sandwiches_(Oamc),
#  R_Breakfast_Banana_Split,
#  R_Breakfast_Burritos_for_the_Freezer,
#  R_Breakfast_Casserole_from_Southern_Living,
#  R_Breakfast_Cookies,
#  R_Breakfast_Delight_Rounds,
#  R_Breakfast_Loaf,
#  R_Breakfast_Migas,
#  R_Breakfast_Pizza,
#  R_Breakfast_Quesdadillas_for_2,
#  R_Breakfast_Quiche,
#  R_Breakfast_Stir_Fry,
#  R_Brenda's_Famous_Potato_Salad,
#  R_Brewed_Orange_Cinnamon_Coffee,
#  R_Brewhaus_Potato_Salad,
#  R_Briana's_Zesty_Spaghetti_Sauce,
#  R_Brie_and_Apple_Panini,
#  R_Brigadeiro_(Brazilian_Docinho),
#  R_Brilliant_Chicken_Caesar_Wrap,
#  R_Brined_Pork_Chops,
#  R_Bringing_Home_Baby_Carrots,
#  R_Brioche,
#  R_Brisket,
#  R_British_Scones,
#  R_Broccoli,_Cheese_and_Potato_Soup,
#  R_Broccoli_&amp;_Onion_Casserole,
#  R_Broccoli_Casserole,
#  R_Broccoli_Cauliflower_Salad,
#  R_Broccoli_Cheese_Skillet_Potatoes,
#  R_Broccoli_Crunch_Salad,
#  R_Broccoli_Lovers_Casserole_II,
#  R_Broccoli_Pasta_With_Creamy_Garlic_Dressing,
#  R_Broccoli_Potatoes,
#  R_Broccoli_Rabe,_White_Bean,_and_Fontina_Pasta,
#  R_Broccoli_Salad,
#  R_Broccoli_Salad_With_Gouda,
#  R_Broccoli__Slaw,
#  R_Broccoli_and_Bell_Peppers,
#  R_Broccoli_and_Eggs,
#  R_Broiled_Garlic_Mussels_(Moules_Gratiees_),
#  R_Broiled_Honey_mustard_Chicken_Sandwiches,
#  R_Broiled_Salmon_With_Chili_Glaze,
#  R_Broiled_Shrimp,
#  R_Broiled_Tuna_Teriyaki,
#  R_Broiled_Turkey_over_Spinach,
#  R_Brown_Bag_Apple_Salad,
#  R_Brown_Rice_Perfection,
#  R_Brown_Rice_Salad,
#  R_Brown_Rice_With_Onions,_Garlic,_and_Pecans,
#  R_Brown_Rice_in_the_Rice_Cooker,
#  R_Brown_Sugar_Brownies,
#  R_Brown_Sugar_Oatmeal_Muffins,
#  R_Brown_Sugar_Peach_Cake,
#  R_Brown_Sugar_Pound_Cake,
#  R_Brown_Sugar_Turkey_Meatloaf,
#  R_Brown_Sugar_Walnut_Cookies,
#  R_Browned_Butter_and_Hazelnut_Mashed_Potatoes,
#  R_Brownie_Bottom_Cheesecake,
#  R_Brownies_Agave,
#  R_Brunch_Bellinis,
#  R_Brunch_Egg_Dish_Florentine,
#  R_Brunch_Style_Stuffed_Acorn_Squash_(Paleo),
#  R_Bruschetta_III,
#  R_Bruschetta_Sundae,
#  R_Brussel_Sprouts___1_2_Point_With_Weight_Watchers,
#  R_Brussels_Sprouts,
#  R_Brussels_Sprouts_Vinaigrette,
#  R_Brussels_Sprouts_With_Almonds_and_Lemon_Rind,
#  R_Brussels_Sprouts_With_Chestnut_Butter,
#  R_Brussels_Sprouts_in_Onion_Butter,
#  R_Brussels_and_Shrooms_Saute,
#  R_Brussels_sprouts,_with_butter_sauce,_Americano,
#  R_Buca_Di_Beppo_Macaroni_Rosa_(Copycat),
#  R_Bucatini_With_Pancetta,_Cheese_and_Eggs,
#  R_Bucatini_With_Pancetta_And_Tomatoes,
#  R_Buck's_Fizz___Champagne_and_Orange_Cocktail,
#  R_Buckeyes,
#  R_Buckin'_Hot_Sauce,
#  R_Buckwheat_Cheddar_Blini_With_Smoked_Salmon,
#  R_Buckwheat_and_Yam_Tortillas_With_Stir_Fry,
#  R_Buffalo_Chicken_Dip,
#  R_Buffalo_Chicken_Sandwiches,
#  R_Buffalo_Chicken_Tenders_or_Fingers,
#  R_Buffalo_Perogies,
#  R_Bulgur_Wheat_Tabbouleh_With_Chickpeas,
#  R_Bunelos_(Dessert),
#  R_Bunny's_Carrot_Cake_Martini,
#  R_Bunuelos_(Fried_Sweet_Puffs),
#  R_Bunya_Calda_(Or_Banya_Cauda),
#  R_Burnished_Bananas,
#  R_Burrito_Pita_Pockets,
#  R_Bush_Tomato_Damper,
#  R_Bushwacker,
#  R_Bushwhacker,
#  R_Busy_Day_Meatloaf,
#  R_Buttercream,
#  R_Buttered_Mango,
#  R_Buttered_Oat_Breadsticks,
#  R_Buttered_Rum_Muffins,
#  R_Butterfinger_Cookie_Mix_(Gift_in_a_Jar),
#  R_Buttermilk_Panna_Cotta_With_Rhubarb_Cherry_Compote,
#  R_Buttermilk_Pudding_With_Fresh_Fruit,
#  R_Butternut_Squash_Macaroni_and_Cheese,
#  R_Butternut_Squash_Risotto_With_Spinach_and_Toasted_Pine_Nuts,
#  R_Butternut_Squash_Soup_With_Vegetable_Stock,
#  R_Butternut_Squash_With_Pecans,
#  R_Butterscotch_Confetti_Square,
#  R_Butterscotch_Treat,
#  R_Butterscotch_Truffle_Martini,
#  R_Butterscotch_or_Chocolate_Clusters,
#  R_Buttery_Potato_Crusted_Fish,
#  R_Buttery_Stuffed_Mushroom_Bread,
#  R_CHICKEN_CASSEROLE_IN_A_SESAME_GINGER_SAUCE,
#  R_C_Hudson's_Ham_&_Potato_Casserole,
#  R_Cabbage_Casserole,
#  R_Cabbage_Casserole_With_Leeks_and_Pine_Nuts,
#  R_Cabbage_Pie,
#  R_Cabbage_Salad_Cups,
#  R_Cabbage_and_Pork_Sausage___Tripp_Sausage,
#  R_Cactus_Margarita,
#  R_Cactus_Paddle_Salad_(Nopales_Salad),
#  R_Caesar_Burgers,
#  R_Caesar_Chicken_With_Orzo,
#  R_Caesar_Salad,
#  R_Caf&eacute;_De_Olla:_Sweet_Cinnamon_Coffee,
#  R_Caf&eacute;_Noir,
#  R_Cafe_Liegeois,
#  R_Cafe_Mocha,
#  R_Cafe_Pasqual's_Cilantro_Rice,
#  R_Caffe_Borgia_Cake,
#  R_Cajun_Casserole,
#  R_Cajun_Chicken_Lasagna,
#  R_Cajun_Chicken_Linguine,
#  R_Cajun_Chicken_and_Linguine,
#  R_Cajun_Country_Roasted_Potatoes,
#  R_Cajun_Halibut,
#  R_Cajun_Marinated_Pork_Chops,
#  R_Cajun_Meat_Loaf_With__a_Cool_Tomato_Salsa,
#  R_Cajun_Meatballs,
#  R_Cajun_Pecan_Catfish,
#  R_Cajun_Shrimp_Burger,
#  R_Cajun_Shrimp_and_Mashed_Cauliflower,
#  R_Cake_Mix_Cinnamon_Rolls,
#  R_Cake_Mix_Extender_I,
#  R_Cake_Mix_Frosting,
#  R_Calamari_in_Creamy_Wine_Sauce,
#  R_Calci_Yum_Protein_Drink,
#  R_Calee,
#  R_Calf_Liver_and_Onions_With_Bacon,
#  R_Calico_Peas,
#  R_Calming_Cedar_Tea,
#  R_Cambodian_Eggplant_With_Pork_and_Shrimp,
#  R_Campbell's_Macaroni_and_Cheese,
#  R_Campbells_Chicken_With_Sun_Dried_Tomatoes,
#  R_Camper's_Breakfast_Hash,
#  R_Campfire_Coffee_Can_Casserole,
#  R_Canadian_Apple_Fritters,
#  R_Canadian_Bacon,_Apples_and_Potatoes,
#  R_Canadian_Bacon,_Bagel,_and_Green_Pepper_Sandwiches,
#  R_Canadian_Kebabs,_Eh?__(Zwt_II),
#  R_Canadian_Killer_Kool_Aid_Recipe,
#  R_Canadian_Oven_Roasted_Potatoes,
#  R_Candied_Jalapenos,
#  R_Candy_Crunch_Pudding_Pie,
#  R_Cannoli_Cake,
#  R_Cantaloupe_Melba,
#  R_Cantaloupe_Pie_Ala_Texas_and_Pacific,
#  R_Cantaloupe_and_Cucumber_Salad,
#  R_Caponata,
#  R_Cappuccino_Nanaimo_Bars,
#  R_Capt._Phil's_Crab_Stuffed_Mushrooms,
#  R_Captivating_Champagne,
#  R_Caramel_Bread_Pudding_Pie,
#  R_Caramel_Candy_Bars,
#  R_Caramel_Cheesecake_With_Hazelnut_Crust,
#  R_Caramel_Cinnamon_Latte,
#  R_Caramel_Corn,
#  R_Caramel_Icing,
#  R_Caramel_Pears_Belle_Helene,
#  R_Caramel_Pecan_Cookies,
#  R_Caramel_Pecan_Squares,
#  R_Caramel_Pecan___Pumpkin_Bread_Puddings,
#  R_Caramel_Sauce,
#  R_Caramel_Snack_Attack_Mix,
#  R_Caramel_Snack_Mix,
#  R_Caramelised_Strawberries_on_a_Bed_of_Cottage_Cheese_and_Mint,
#  R_Caramelized_Applesauce_With_Pecans_and_Golden_Raisins,
#  R_Caramelized_Banana_Buttermilk_Ice_Cream,
#  R_Caramelized_Onion_Dip,
#  R_Caramelized_Onion_and_Sour_Cream_Spread,
#  R_Carbonara_Healthier_With_Greens,
#  R_Cardamom_Banana_Bread,
#  R_Cardamom_Cheesecake_Bars,
#  R_Cardamom_Cookies___Kardemommekager,
#  R_Cardamom_Tea,
#  R_Caribbean_Bananas,
#  R_Caribbean_Bar_Nuts___Low_Carb___No_Salt_Added,
#  R_Caribbean_Jerk_Chicken,
#  R_Caribbean_Shrimp_and_Vegetable_Soup,
#  R_Caribbean_Sweet_Potato_Coconut_Soup,
#  R_Carne_Asada_Sandwiches_With_Chipotle_Mayonnaise,
#  R_Carnes_Desmenuzadas_(Shredded_Beef),
#  R_Carol's_Muffalletto,
#  R_Carolina_Style_Barbecue_Chicken,
#  R_Carpetbag_Steak,
#  R_Carrabba's_Chicken_Bryan,
#  R_Carrot,_Apple,_and_Horseradish_Salad,
#  R_Carrot_&amp;_Caraway_Slaw,
#  R_Carrot_Bars,
#  R_Carrot_Cumin_Soup_With_Toasted_Pecans,
#  R_Carrot_Layer_Cake_With_Cream_Cheese_Frosting,
#  R_Carrot_Maple_Cheesecake,
#  R_Carrot_Muffins,
#  R_Carrot_Oatmeal_Cookies,
#  R_Carrot_Pineapple_Layer_Casserole,
#  R_Carrot_Salad_With_Pineapple_(No_Mayo),
#  R_Carrot_and_Grapefruit_Soup,
#  R_Carrot_and_Potato_Gratin,
#  R_Carrot_nut_bean_burger,
#  R_Cassata_Cake,
#  R_Cat_Cora's_Saffron_Honey_Roasted_Chicken,
#  R_Catfish_Masala,
#  R_Catherine's_Wammy_____a_Halloween_Adult_Drink,
#  R_Cathy's_Lasagne,
#  R_Cauliflower_Ham_Chowder,
#  R_Cauliflower_Soup,
#  R_Cauliflower_Soup_With_Croutons__Ww,
#  R_Cauliflower_With_Herbed_Crumb_Topping,
#  R_Cauliflower_and_Broccoli_Flan_With_Spinach_Bechamel_Sauce,
#  R_Cauliflower_and_Brussels_Sprouts,
#  R_Cauliflower_and_Cheese_Pakora,
#  R_Cauliflower_and_Chicken_Casserole,
#  R_Cauliflower_in_a_Caper_Vinaigrette,
#  R_Cauliflower_with_Lemon,
#  R_Cebollas_Curtidas_(Mexican_Pickled_Onions),
#  R_Cedar_Planked_Salmon_With_Citrus_BBQ_Sauce,
#  R_Celery_Almond_Casserole,
#  R_Celery_Radish_and_Olive_Salad,
#  R_Cevapcici_(Cevapi)_Balkan_Sausage_Sandwiches,
#  R_Champagne_Raspberry_Sauce,
#  R_Charishma's_Okra_Sweet_Corn_Veggie_Delight,
#  R_Charlotte's_Southern_Cornbread_Dressing,
#  R_Chau_Fan_(Shrimp_Fried_Rice),
#  R_Chayote_Salad,
#  R_Cheaters_Pumpkin_Spice_Cheesecake,
#  R_Cheddar_Applesauce_Muffins,
#  R_Cheddar_Broccoli_Bake,
#  R_Cheddar_Bruschetta,
#  R_Cheddar_Gorgeous!_Cheese_and_Onion_Bread_and_Butter_Pudding,
#  R_Cheddary_Chicken_Pot_Pie,
#  R_Cheerios_Jumbo_Breakfast_Cookies,
#  R_Cheese_&amp;_Pesto_Bites,
#  R_Cheese_Enchiladas_With_Green_Sauce,
#  R_Cheese_Filled__Chicken_Cutlets,
#  R_Cheese_Frankfurters,
#  R_Cheese_Joes,
#  R_Cheese_Nip_Broccoli_Casserole,
#  R_Cheese_Onions,
#  R_Cheese_Pie,
#  R_Cheese_Ravioli_With_Pumpkin_Sage_Sauce,
#  R_Cheese_Rosti,
#  R_Cheese_Steak_Crescent_Pizza,
#  R_Cheese_Stuffed_Pecans,
#  R_Cheese_Stuffed_Rolls,
#  R_Cheese_Tortellini_With_Cannellini_Bean_Sauce,
#  R_Cheese_and_Chutney_Turnover,
#  R_Cheese_and_Egg_Puffs,
#  R_Cheese_and_Garlic_Drop_Biscuits,
#  R_Cheese_and_Jalapeno_Grits_Casserole,
#  R_Cheeseburger_Ole_Soup,
#  R_Cheesecake_Filled_Pumpkin_Cupcakes,
#  R_Cheesy_Asparagus,
#  R_Cheesy_Brunch_Roll_Ups,
#  R_Cheesy_Cheez_It_Mac_&amp;_Cheese,
#  R_Cheesy_Chicken_&amp;_Veggie_Mac,
#  R_Cheesy_Chicken_'n_Broccoli_Simmer,
#  R_Cheesy_Chicken_Burger_W__Corn_&amp;_Carrot_Relish,
#  R_Cheesy_Chicken_for_50,
#  R_Cheesy_Corn_Dog_Bake,
#  R_Cheesy_Corn_Fritters,
#  R_Cheesy_Corn_on_Rye_(21_Day_Wonder_Diet_:_Day_2_),
#  R_Cheesy_Cornbread,
#  R_Cheesy_Crust_Roasted_Haddock,
#  R_Cheesy_Grits_Casserole,
#  R_Cheesy_Ham_&amp;_Broccoli_Casserole,
#  R_Cheesy_Italian_Wedding_Soup,
#  R_Cheesy_Mostaccioli,
#  R_Cheesy_Potato_Bake,
#  R_Cheesy_Potato_Casserole,
#  R_Cheesy_Potato_Lasagna,
#  R_Cheesy_Sausage_Penne,
#  R_Cheesy_Sausage_and_Tomato_Manicotti_(Oamc),
#  R_Cheesy_Spinach_Pasta_With_Scallops,
#  R_Cheesy_Spinach_and_Mushroom_Pita_Pocket,
#  R_Cheesy_Steak_Sandwich_Pockets,
#  R_Cheesy_Tuna_Casserole,
#  R_Cheesy_Vegetable_Pasta,
#  R_Cheesy_Veggie_Chowder,
#  R_Chef's_Jon's_Italian_Bruschetta,
#  R_Chef_Flower's_Simple_Avocado_Dip,
#  R_Cherried_Chicken,
#  R_Cherries_Jubillee_Sundaes,
#  R_Cherry_Almond_Cheesecake_Cookie_Cups,
#  R_Cherry_Angel_Dessert,
#  R_Cherry_Angel_Food_Cake_&amp;_Cherry_Fluff_Frosting,
#  R_Cherry_Heart_Pie,
#  R_Cherry_Limeade_for_One,
#  R_Cherry_Mascarpone_Cream_Scones,
#  R_Cherry_Rolls,
#  R_Cherry_Swirl_Brownies,
#  R_Cherry_Tomato_Gratin,
#  R_Cherry_Tomato_Mozzarella_Saute,
#  R_Cherry_Tomato_Salad_With_Blue_Cheese,
#  R_Cherry_and_Dark_Chocolate_Ice_Cream,
#  R_Chestnut_Sour_Cream_Coffee_Cake,
#  R_Chewy_Chocolate_Soy_Smoothie,
#  R_Chewy_Macaroon_Pie,
#  R_Chica_Iced_Tea_(South_American_Style),
#  R_Chicago_Style_Pizza_Crust:_Take_25,
#  R_Chick_Fil_A_Chicken_(And_Nuggets)_Copycat,
#  R_Chick_N_Que_Sauce,
#  R_Chicken,_Artichoke_&amp;_Spinach_Casserole,
#  R_Chicken,_Fennel_and_Tomato_Ragout,
#  R_Chicken,_Grape_and_Curry_Salad,
#  R_Chicken,_Pasta,_and_Chickpea_Stew,
#  R_Chicken,_Roasted_Capsicum,_Feta_and_Walnut_Pasta_Salad,
#  R_Chicken,_Tomato,_Zucchini,_and_Orzo_Stew,
#  R_Chicken,sausages_and_peppers_with_pasta,
#  R_Chicken_&_Broccoli_Cannelloni,
#  R_Chicken_&_Crispy_Tortilla_Soup,
#  R_Chicken_&_Handmade_Noodle_Soup,
#  R_Chicken_&amp;_Artichoke_Lasagne,
#  R_Chicken_&amp;_Brown_Rice_Casserole,
#  R_Chicken_&amp;_Mushroom_Lasagne,
#  R_Chicken_&amp;_Pumpkin_Curry_(21_Day_Wonder_Diet:_Day_13),
#  R_Chicken_&amp;_Sausage_Al_Forno,
#  R_Chicken_&amp;_Sausage_Gumbo,
#  R_Chicken_65_(4_Variations),
#  R_Chicken_Adobo,
#  R_Chicken_Amandine,
#  R_Chicken_Bell_Peppers_Onions_and_Mushrooms_With_Marsala,
#  R_Chicken_Bouillabaisse_(For_the_Slow_Cooker),
#  R_Chicken_Braised_with_40_Cloves_of_Garlic,
#  R_Chicken_Breast_Stuffed_With_Apple_and_Goat_Cheese,
#  R_Chicken_Breast_With_Red_Pepper_Cream_Sauce,
#  R_Chicken_Breasts_Royal,
#  R_Chicken_Breasts_With_Mushrooms,
#  R_Chicken_Breasts_With_Mushrooms_and_Tarragon,
#  R_Chicken_Broccoli_Casserole_W__Cheese,
#  R_Chicken_Burgurs,
#  R_Chicken_Cacciatore,
#  R_Chicken_Cakes_With_Avocado_Mayonnaise_and_Tomato_Salsa,
#  R_Chicken_Chow_Mein_Casserole,
#  R_Chicken_Cobbler_Casserole,
#  R_Chicken_Coleslaw,
#  R_Chicken_Cordon_Bleu_in_Pastry,
#  R_Chicken_Curry,
#  R_Chicken_Delight,
#  R_Chicken_Enchilada,
#  R_Chicken_Enchiladas,
#  R_Chicken_Enchiladas_El_Travis,
#  R_Chicken_Fajitas,
#  R_Chicken_Feed,
#  R_Chicken_Fettuccine_a_La_Fuente,
#  R_Chicken_Francaise,
#  R_Chicken_Fried_Pork_With_Milk_Gravy,
#  R_Chicken_Fried_Rice_(Low_Gi),
#  R_Chicken_Gnocchi_Veronese_(Olive_Garden),
#  R_Chicken_Hot_Dish,
#  R_Chicken_Jambalaya_Packets,
#  R_Chicken_Jerusalem,
#  R_Chicken_Kiev,_a_Yummy_&amp;_Healthy_Version,
#  R_Chicken_Lentil_Soup,
#  R_Chicken_Liver_Pate:_Terrine_De_Foies_De_Volaille,
#  R_Chicken_Mango_Kabobs,
#  R_Chicken_Marsala___Ala_Olive_Garden,
#  R_Chicken_Mirabella,
#  R_Chicken_Newburg,
#  R_Chicken_Noodle_Soup_(Ina_Garten's_Recipe),
#  R_Chicken_Parmesan_Alfredo,
#  R_Chicken_Parmesan_With_Fresh_Mozzarella_and_Fresh_Basil,
#  R_Chicken_Parmesan_for_Crock_Pot,
#  R_Chicken_Piccata,
#  R_Chicken_Pizza_Florentine,
#  R_Chicken_Pot_Pie_With_Biscuit_Topping,
#  R_Chicken_Provencale,
#  R_Chicken_Ranch_Pizza,
#  R_Chicken_Rollatini_With_Cheese,_Ham_&amp;_Spinach,
#  R_Chicken_Roni_Casserole,
#  R_Chicken_Salad,
#  R_Chicken_Salad_With_Craisins_and_Almonds,
#  R_Chicken_Salad_With_Sauteed_Mushrooms,
#  R_Chicken_Salad_for_an_Endless_Summer,
#  R_Chicken_Sate_With_Peanut_Sauce,
#  R_Chicken_Saute_With_Artichokes,_Lemon_and_Mint,
#  R_Chicken_Scaloppine,
#  R_Chicken_Scampi,
#  R_Chicken_Soup_for_Dummies,
#  R_Chicken_Souvlaki,
#  R_Chicken_Spiedies,
#  R_Chicken_Spinach_Salad_With_Raspberries,
#  R_Chicken_Strawberry_Salad_W__Goat_Cheese,
#  R_Chicken_Stuffed_&quot;_Chili&quot;_Bell_Peppers,
#  R_Chicken_Supreme,
#  R_Chicken_Tarragon_Casserole,
#  R_Chicken_Tenders_With_Spicy_Rice_and_Red_Peppers,
#  R_Chicken_Tetrazzini,
#  R_Chicken_Tortilla_Rolls,
#  R_Chicken_Tortilla_Soup,
#  R_Chicken_Under_a_Brick__(Abs_Diet),
#  R_Chicken_With_Creamy_Mustard_Chive_Sauce,
#  R_Chicken_With_Fresh_Tomato_Cilantro_Cream_Sauce,
#  R_Chicken_With_Garlic,_Basil_&amp;__Parsley,
#  R_Chicken_With_Lime_Sauce,
#  R_Chicken_With_Noodles_and_Vegetables_(Ww),
#  R_Chicken_With_Olives,
#  R_Chicken_With_Quinoa,
#  R_Chicken_With_Rice_and_Fruit_Salad,
#  R_Chicken_With_Toasted_Walnut_and_Coriander_Sauce,
#  R_Chicken_With_Tomatoes_and_Olives,
#  R_Chicken_With_Water_Chestnuts,
#  R_Chicken_Wrap,
#  R_Chicken_a_La_Greque,
#  R_Chicken_a_La_Queen_;),
#  R_Chicken_and_Asparagus_Skillet_Supper,
#  R_Chicken_and_Biscuits_from_Scratch,
#  R_Chicken_and_Black_Bean_Chili__Crock_Pot,
#  R_Chicken_and_Creamy_Spinach_Crustless_Quiche,
#  R_Chicken_and_Dressing_Casserole,
#  R_Chicken_and_Green_Chili_Enchiladas,
#  R_Chicken_and_Mushroom_Casserole_II,
#  R_Chicken_and_Mushroom_Goulash_With_Gnocchi,
#  R_Chicken_and_Provolone_Salad_Sandwiches,
#  R_Chicken_and_Rice_Casserole,
#  R_Chicken_and_Rice_in_Wine_herb_Sauce,
#  R_Chicken_and_Roasted_Pepper_Panini,
#  R_Chicken_and_Salad_Pizza(Flat_Belly_Diet_Recipe),
#  ...]

# %%
# The problem is solved using PuLP's choice of Solver
prob.solve()
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/lolitalolita/opt/anaconda3/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/j9/7y5q0v6x4p3f2fdr5f5ffl0m0000gn/T/a364f59333e64753942fce4627ccec45-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/j9/7y5q0v6x4p3f2fdr5f5ffl0m0000gn/T/a364f59333e64753942fce4627ccec45-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 13 COLUMNS
# At line 43200 RHS
# At line 43209 BOUNDS
# At line 43210 ENDATA
# Problem MODEL has 8 rows, 4941 columns and 39244 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 7 (-1) rows, 4924 (-17) columns and 34286 (-4958) elements
# 0  Obj 0 Primal inf 242.83033 (3)
# 4  Obj 1.9230129e-16
# Optimal - objective value 0
# After Postsolve, objective 0, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0 - 4 iterations time 0.012, Presolve 0.01
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.04
# 1

# %%
# The status of thesolution is printed to the screen
print("Status:", LpStatus[prob.status])
# Out:
# Status: Optimal

# %%
# Each of the variables is printed with it's resolved optimum value
    
for v in prob.variables():
    if v.varValue>0:
        print(v.name, "=", v.varValue)
# Out:
# R_3_Spice_Fuss_Free_Fish_Fillet_Curry = 24.966443
# R_Ann's_Easy_Posole = 19.328859
# R_Baileys_Mint_Chocolate_Martini = 22.613268
# R_Jello_Fruit_Bars = 222.81879

# %%
# The optimised objective function value is printed to the screen
print("Minimal cholesterol intake = ", value(prob.objective))
# Out:
# Minimal cholesterol intake =  0.0
