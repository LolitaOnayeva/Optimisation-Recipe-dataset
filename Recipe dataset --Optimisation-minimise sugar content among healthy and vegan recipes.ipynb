# %%
import pandas as pd
import numpy as np
import csv
from pathlib import Path 
import re
import string

# %%
df= pd.read_csv(r'/Users/lolitalolita/Downloads/recipes.csv')

# %%
# Get healthy and vegan recipes 

df=df[df['RecipeCategory'].isin(['Healthy','Vegan'])]

# %%
# Get calories and content per one serving
df_per_serving=df[['Calories','CholesterolContent','CarbohydrateContent','SugarContent','ProteinContent']].div(df.RecipeServings, axis=0)

# %%
df['RecipeCategory'].unique()
# Out:
# array(['Vegan', 'Healthy'], dtype=object)

# %%
df
# Out:
#        RecipeId                                               Name  \
# 195      236464                      Sweet and Sour Cucumber Salad
# 496      512214        Gluten Free Vegan Zucchini Eggplant Lasagna
# 796      455919                           Ginger Lime Fish Parcels
# 847       94335                      Salmon With Chili-honey Glaze
# 1008     201755                      Tibetan Style Seitan Burritos
# ...         ...                                                ...
# 41689    450356                           Marie's Tilapia Marinara
# 42779    472204            America's Test Kitchen Thin-Crust Pizza
# 42847    503736  3 Ingredient Individual Quinoa Pizza Crust (No...
# 42927    127988               Ww 4 Points - Cinnamon Pepper Shrimp
# 42958    211611                                   Shrimp and Chips
#
#       RecipeCategory  Calories  CholesterolContent  CarbohydrateContent  \
# 195            Vegan      52.1                 0.0                 12.5
# 496            Vegan     223.1                 2.2                 29.6
# 796          Healthy     114.4                61.6                  6.5
# 847          Healthy     232.9                78.8                 15.2
# 1008           Vegan     195.5                 0.0                 28.4
# ...              ...       ...                 ...                  ...
# 41689        Healthy     745.6               178.2                 89.0
# 42779        Healthy     184.5                12.8                 25.6
# 42847        Healthy     297.2                 0.0                 48.9
# 42927        Healthy     197.0               172.8                  9.8
# 42958        Healthy     306.5                53.6                 52.2
#
#        SugarContent  ProteinContent  RecipeServings  HighScore
# 195             6.2             2.1               2          1
# 496            15.8            12.1               8          1
# 796             4.7            17.3               4          0
# 847            13.8            30.5               4          1
# 1008            6.3             4.2               6          0
# ...             ...             ...             ...        ...
# 41689           6.7            51.7               2          1
# 42779           2.0             7.4              16          1
# 42847           0.1            10.0               1          1
# 42927           3.8            24.7               2          0
# 42958           0.2            12.8               2          0
#
# [175 rows x 10 columns]

# %%
# Import PuLP modeler functions
from pulp import *

# %%
# Create the 'prob' variable to contain the problem data
prob = LpProblem("The Food Emissions Problem", LpMinimize)
# Out:
# /Users/lolitalolita/opt/anaconda3/lib/python3.9/site-packages/pulp/pulp.py:1352: UserWarning: Spaces are not permitted in the name. Converted to '_'
#   warnings.warn("Spaces are not permitted in the name. Converted to '_'")

# %%
Name_dict = list(df['Name'])

Calories_dict = dict(zip(Name_dict, df_per_serving['Calories']))
CholesterolContent_dict = dict(zip(Name_dict , df_per_serving['CholesterolContent']))
CarbohydrateContent_dict = dict(zip(Name_dict , df_per_serving['CarbohydrateContent']))
SugarContent_dict = dict(zip(Name_dict, df_per_serving['SugarContent']))
ProteinContent_dict = dict(zip(Name_dict, df_per_serving['ProteinContent']))

# %%
# A dictionary called 'ingredient_vars' is created to contain the referenced Variables
recipe_name_vars = LpVariable.dicts("R", Name_dict, 0)

# %%
# The objective function is added to 'prob' first
prob += (
    lpSum([SugarContent_dict[i] * recipe_name_vars[i] for i in Name_dict]),
    "Total sugar content per dish",)

# %%
# The constraints are added to 'prob'
#prob += lpSum([recipe_name_vars[i] for i in Name_dict]) == 100, "PercentagesSum"
prob += lpSum([recipe_name_vars[i] for i in Name_dict]) 

prob += (
    lpSum([Calories_dict[i] * recipe_name_vars[i] for i in Name_dict]) <= 2000.0,
    "Calories_dict_Requirement_max",
)
prob += (
    lpSum([Calories_dict[i] * recipe_name_vars[i] for i in Name_dict]) >= 1500.0,
    "Calories_dict_Requirement_min",
)


prob += (
    lpSum([CholesterolContent_dict[i] * recipe_name_vars[i] for i in Name_dict]) <= 13.0,
    "CholesterolContent_Requirement_max",
)
prob += (
    lpSum([CholesterolContent_dict[i] * recipe_name_vars[i] for i in Name_dict]) >= 5.0,
    "CholesterolContent_Requirement_min",
)

prob += (
    lpSum([CarbohydrateContent_dict[i] * recipe_name_vars[i] for i in Name_dict]) <= 150.0,
    "CarbohydrateContent_Requirement_max",
)

prob += (
    lpSum([CarbohydrateContent_dict[i] * recipe_name_vars[i] for i in Name_dict]) >= 120.0,
    "CarbohydrateContent_Requirement_min",
)

prob += (
    lpSum([ProteinContent_dict[i] * recipe_name_vars[i] for i in Name_dict]) <= 112.0,
    "ProteinContent_Requirement_max",
)
prob += (
    lpSum([ProteinContent_dict[i] * recipe_name_vars[i] for i in Name_dict]) >= 70.0,
    "ProteinContent_Requirement_min",
)
# Out:
# /Users/lolitalolita/opt/anaconda3/lib/python3.9/site-packages/pulp/pulp.py:1704: UserWarning: Overwriting previously set objective.
#   warnings.warn("Overwriting previously set objective.")

# %%
# The problem data is written to an .lp file
prob.writeLP("RecipeModel.lp")
# Out:
# [R_3_2_1_Shrimp,
#  R_3_Ingredient_Individual_Quinoa_Pizza_Crust_(No_Soaking!),
#  R_Air_Fryer_Crispy_Panko_Shrimp,
#  R_America's_Test_Kitchen_Thin_Crust_Pizza,
#  R_Apple_Butter_Pie,
#  R_Asian_Sesame_Cod,
#  R_Azerbaijani_Pomegranate_and_Spinach_Soup_(Vegan),
#  R_BBQ_Pork_Fried_Rice,
#  R_Baked_Orange_Salmon,
#  R_Baked_Pasta_With_Sausage,_Tomatoes,_and_Cheese,
#  R_Baked_Pesto_Pasta_With_Tomato_&_Cheese,
#  R_Baked_Salmon_Fish_Sticks,
#  R_Barbecued_Salmon__and__Easy_Marinade,
#  R_Bean,_Tomato,_&amp;_Butternut_Squash_Soup,
#  R_Beans_Bourguignon,
#  R_Beer_Batter,
#  R_Best_Ever_Spicy_Boiled_Shrimp,
#  R_Butternut_Ginger_Soup,
#  R_Caramel_Sweetened_Condensed_Milk,
#  R_Caraway_Noodles,
#  R_Carne_Apache,
#  R_Carrot_Bisque,
#  R_Carrot_and_Cashew_Nut_Roast,
#  R_Chicken,_Potato_and_Vegetable_Bake,
#  R_Chicken,_Shrimp,_and_Ham_Jambalaya,
#  R_Chicken__Sweet_and_Spunky,
#  R_Chicken_and_Rice_Casserole,
#  R_Chinese_Buffet_Black_Pepper_Chicken,
#  R_Cream_of_Mushroom_Soup_(Raw_Food),
#  R_Creamy_Carrot_Rice,
#  R_Creamy_Garlic_Shrimp,
#  R_Creamy_Shrimp_and_Pasta,
#  R_Crispy_Baked_Eggplant_(Aubergine),
#  R_Crock_Pot_Vegetable_Medley,
#  R_Crunchy_Fried_Shrimp,
#  R_Dark_Meat_Seitan,
#  R_Deep_Fried_Fish,
#  R_Deep_Fried_Mushrooms,
#  R_Delicious_Homemade_Egg_Noodles,
#  R_Dog_Treat_Cookies,
#  R_Doggie_Biscotti_Banana_Treats,
#  R_Downeast_Raspberry_Cake,
#  R_Dried_Onion_Slices,
#  R_Drunken_Grilled_Key_Lime_Shrimp,
#  R_Fettuccine_With_Shrimp,
#  R_Fish_With_Broccoli,_Baked_Potato,_and_Cheese_Sauce_(Lite_Bleu),
#  R_Fish_With_Lemon_Butter,
#  R_Fish_and_Chips,
#  R_Flax_Quinoa_Crackers_(Gluten_Free),
#  R_Flounder_Fillets_in_Cornmeal_Mustard_Crust,
#  R_Fried_Stuffed_Olives,
#  R_Fusilli_Bucati_Lunghi_With_Roasted_Red_Pepper_Sauce,
#  R_Garlic_Prawns_With_Risoni,_Tomato_&amp;_Artichoke,
#  R_Garlic_Shrimp_and_Pasta,
#  R_Ginger_Lime_Fish_Parcels,
#  R_Gluten_Free_Vegan_Zucchini_Eggplant_Lasagna,
#  R_Golden_Rice_Pilaf,
#  R_Gourmet_Pearl_Couscous_Salad_With_Vegetables_and_Cashew_Nuts_and,
#  R_Grilled_Chicken_Alfredo,
#  R_Grilled_Tropical_Shrimp,
#  R_Hangover_Shrimp,
#  R_Helen's_Cheese_Rice,
#  R_Herb_Encrusted_Seitan,
#  R_Homemade_Chicken_Noodle_Soup_With_Hand_Made_Egg_Noodles,
#  R_Homemade_Herb_Seasoning,
#  R_Homemade_Pasta_Dough,
#  R_Homemade_Spaetzle,
#  R_Honey_Grilled_Shrimp,
#  R_How_to_Season_Cast_Iron_Pans,
#  R_Hush_Puppies,
#  R_Ida's_Fishcakes,
#  R_Imitation_Crab_Meat_Cakes,
#  R_Instant_Pot_Bourbon_BBQ_Chicken,
#  R_Italian_Baked_Bluefish,
#  R_Jamika's_Salmon_With_Pineapple_Salsa,
#  R_Kidney_Bean_Salad_Spread_or_Dip,
#  R_Lemon_Garlic_Shrimp_&amp;_Vegetables,
#  R_Lemon_Shallot_Scallops___Weight_Watcher_Friendly,
#  R_Lemon_rice_soup,
#  R_Lemony_Chicken_Pasta,
#  R_Lentil_Loaf,
#  R_Lentils_With_Chickpeas_and_Couscous,
#  R_Linguine_with_Spicy_Parsley_Clam_Sauce,
#  R_Linguine_with_Spicy_Shrimp_Sauce,
#  R_Little's_Iranian_Pancakes,
#  R_Lou_Malnati's_Chicago_Stylepizza_Crust___Dough,
#  R_Low_Fat_Garlic_Prawns,
#  R_Low_Fat_Minestrone,
#  R_Low_Fat_Turkey_Chalupa,
#  R_Mabel_Drake's_Three_Bean_Salad,
#  R_Macaroni_and_4_Cheeses,
#  R_Maple_Glazed_Salmon_With_Pineapple,
#  R_Marie's_Tilapia_Marinara,
#  R_Martha's_Chicken_Soup_With_Parsley_Dumplings,
#  R_Memphis_Cornmeal_Battered_Cod,
#  R_Minestrone_(Volumetrics),
#  R_Mini_Elephant_Ears,
#  R_Miso_Salmon,
#  R_Mixed_Greens_with_Tomato_Ginger_Dressing,
#  R_Mushroom_&_Onion_Salisbury_Steak,
#  R_My_Potato_Latkes_(Gluten_Free),
#  R_Mz.jackie's_Chilli_Mac!,
#  R_Nut_Burgers_(Veggie_Burgers),
#  R_Orange_Raspberry_Chicken,
#  R_Oven_Donuts,
#  R_Paella,
#  R_Pampered_Chef_Confetti_Pasta_Salad,
#  R_Pan_Fried_Noodles,
#  R_Panera_Bread_Balsamic_Dipping_Oil,
#  R_Peg's_Old_Canadian_Salmon_Loaf,
#  R_Perfect_Pasta_Dough,
#  R_Pizza_Baguettes,
#  R_Poached_Salmon,
#  R_Polynesian_Pork_Roast,
#  R_Popovers_Pre_1940's,
#  R_Pork_Medallions_With_Cherry_Sauce,
#  R_Pork_Tenderloin_With_Spicy_Apricot_Glaze,
#  R_Potato_and_Parmesan_Gnocchi,
#  R_Pumkpin_Soup,
#  R_Quick_Vietnamese_Fish_in_Caramel_Sauce,
#  R_Raw_Marinated_Mushrooms,
#  R_Restaurant_Style_Salsa_(Pioneer_Woman),
#  R_Roasted_Red_Pepper_Bow_Ties,
#  R_Roasted_Shrimp_and_Orzo,
#  R_Salmon_&amp;_Spinach_Bake,
#  R_Salmon_Croquettes,
#  R_Salmon_With_Chili_honey_Glaze,
#  R_Salmon_and_Potato_Casserole,
#  R_Salmon_on_Greens_With_Lime_Ginger_Dressing,
#  R_Scallops_Charleston,
#  R_Seitan_Log_3__Chick'n_Version,
#  R_Shrimp_Cocktail_With_Sauce,
#  R_Shrimp_Newburg_(Rachael_Ray),
#  R_Shrimp_Vegetable_Stir_Fry,
#  R_Shrimp_W_Spinach_&amp;_Sun_Dried_Tomatoes,
#  R_Shrimp_With_Roasted_Red_Pepper_Cream,
#  R_Shrimp_With_Tomato_Sauce_and_Feta_Cheese,
#  R_Shrimp_and_Chips,
#  R_Shrimp_and_Crab_Meat_With_Rice,
#  R_Shrimp_and_Sausage_Paella,
#  R_Shrimp_or_Onion_Ring_Batter,
#  R_Simple_Avgolemono,
#  R_Simple_Clam_Sauce,
#  R_Skinnygirl_Lower_Fat_Pasta_Carbonara,
#  R_Slow_Cooker_Chicken_Curry,
#  R_Slow_Cooker_Minestrone_Soup,
#  R_Small_Batch_Popovers,
#  R_Soft_Pretzels,
#  R_Southern_Fried_Oysters,
#  R_Spicy_Orange_Ginger_Shrimp_with_Hazelnut_Rice,
#  R_Spicy_Sweet_Grilled_Shrimp,
#  R_Spicy_Turkey_Angel_Hair_Pasta,
#  R_Stir_Fried_Shitake_Mushrooms_With_Tofu_and_Bok_Choy,
#  R_Sweet_and_Sour_Chicken_Balls,
#  R_Sweet_and_Sour_Chicken_Skewers,
#  R_Sweet_and_Sour_Cucumber_Salad,
#  R_Sweet_and_Sour_Shrimp,
#  R_Sweet_and_Spicy_Pumpkin_Seeds,
#  R_Tempeh_Chili,
#  R_Teriyaki_Chicken,
#  R_The_Big_Easy_Spicy_Shrimp,
#  R_Tibetan_Style_Seitan_Burritos,
#  R_Turkey_Ball_Soup,
#  R_Turkey_and_Pasta_With_Peanut_Sauce,
#  R_Udon_Noodle_Salad,
#  R_Vegan_"Cream"_of_Mushroom_Soup,
#  R_Vegan_Banana_Bread_(Healthy!),
#  R_Vegan_Doritos,
#  R_Vegan_Pasta_Casserole,
#  R_Vegan_Wheat_Bran_Muffins,
#  R_Weeknight_Pasta_Salad,
#  R_Ww_4_Points___Cinnamon_Pepper_Shrimp,
#  R_Ww_Glazed_Shrimp_Kabobs___4_Pts.,
#  R_Ww_Spicy_Baked_Shrimp___3_Pts.,
#  R_Zucchini_Yogurt_Multigrain_Muffins]

# %%
# The problem is solved using PuLP's choice of Solver
prob.solve()
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/lolitalolita/opt/anaconda3/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/j9/7y5q0v6x4p3f2fdr5f5ffl0m0000gn/T/b7374b53795e496da09e88ff72976275-pulp.mps timeMode elapsed branch printingOptions all solution /var/folders/j9/7y5q0v6x4p3f2fdr5f5ffl0m0000gn/T/b7374b53795e496da09e88ff72976275-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 13 COLUMNS
# At line 1493 RHS
# At line 1502 BOUNDS
# At line 1503 ENDATA
# Problem MODEL has 8 rows, 175 columns and 1304 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 8 (0) rows, 174 (-1) columns and 1304 (0) elements
# Perturbing problem by 0.001% of 708449.72 - largest nonzero change 0.00070767963 ( 0.0056623223%) - largest zero change 0
# 0  Obj 0 Primal inf 0.7318967 (4)
# 7  Obj 3.97507
# Optimal - objective value 3.9750448
# After Postsolve, objective 3.9750448, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 3.975044815 - 7 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.01
# 1

# %%
# The status of thesolution is printed to the screen
print("Status:", LpStatus[prob.status])
# Out:
# Status: Optimal

# %%
# Each of the variables is printed with it's resolved optimum value
    
for v in prob.variables():
    if v.varValue>0:
        print(v.name, "=", v.varValue)
# Out:
# R_Baked_Orange_Salmon = 0.33591731
# R_Cream_of_Mushroom_Soup_(Raw_Food) = 1.9541966
# R_Flax_Quinoa_Crackers_(Gluten_Free) = 1.6849309

# %%
# The optimised objective function value is printed to the screen
print("Minimal sugar intake = ", value(prob.objective))
# Out:
# Minimal sugar intake =  3.97504481
